# %% [markdown]
# <a href="https://colab.research.google.com/github/run-llama/llama_index/blob/main/docs/docs/examples/agent/multi_document_agents-v1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Multi-Document Agents (V1)
#
# In this guide, you learn towards setting up a multi-document agent over the LlamaIndex documentation.
#
# This is an extension of V0 multi-document agents with the additional features:
# - Reranking during document (tool) retrieval
# - Query planning tool that the agent can use to plan
#
#
# We do this with the following architecture:
#
# - setup a "document agent" over each Document: each doc agent can do QA/summarization within its doc
# - setup a top-level agent over this set of document agents. Do tool retrieval and then do CoT over the set of tools to answer a question.

# %% [markdown]
# If you're opening this Notebook on colab, you will probably need to install LlamaIndex 🦙.

# %%
# %pip install llama-index-core
# %pip install llama-index-agent-openai
# %pip install llama-index-readers-file
# %pip install llama-index-postprocessor-cohere-rerank
# %pip install llama-index-llms-openai
# %pip install llama-index-embeddings-openai
# %pip install unstructured[html]
# Out:
# Collecting llama-index-core
#   Downloading llama_index_core-0.12.10.post1-py3-none-any.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 2.9 MB/s eta 0:00:01
# Collecting numpy
#   Downloading numpy-2.2.1-cp310-cp310-macosx_14_0_arm64.whl (5.4 MB)
#      |████████████████████████████████| 5.4 MB 4.5 MB/s eta 0:00:01
# Collecting filetype<2.0.0,>=1.2.0
#   Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Collecting aiohttp<4.0.0,>=3.8.6
#   Downloading aiohttp-3.11.11-cp310-cp310-macosx_11_0_arm64.whl (455 kB)
#      |████████████████████████████████| 455 kB 8.4 MB/s eta 0:00:01
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core) (1.6.0)
# Collecting typing-inspect>=0.8.0
#   Using cached typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Collecting nltk>3.8.1
#   Using cached nltk-3.9.1-py3-none-any.whl (1.5 MB)
# Collecting deprecated>=1.2.9.3
#   Downloading Deprecated-1.2.15-py2.py3-none-any.whl (9.9 kB)
# Collecting pydantic>=2.8.0
#   Downloading pydantic-2.10.5-py3-none-any.whl (431 kB)
#      |████████████████████████████████| 431 kB 8.9 MB/s eta 0:00:01
# Collecting tqdm<5.0.0,>=4.66.1
#   Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
#      |████████████████████████████████| 78 kB 6.6 MB/s eta 0:00:01
# Collecting networkx>=3.0
#   Using cached networkx-3.4.2-py3-none-any.whl (1.7 MB)
# Collecting PyYAML>=6.0.1
#   Using cached PyYAML-6.0.2-cp310-cp310-macosx_11_0_arm64.whl (171 kB)
# Collecting pillow>=9.0.0
#   Downloading pillow-11.1.0-cp310-cp310-macosx_11_0_arm64.whl (3.1 MB)
#      |████████████████████████████████| 3.1 MB 9.1 MB/s eta 0:00:01
# Collecting dirtyjson<2.0.0,>=1.0.8
#   Using cached dirtyjson-1.0.8-py3-none-any.whl (25 kB)
# Requirement already satisfied: typing-extensions>=4.5.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core) (4.12.2)
# Collecting requests>=2.31.0
#   Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Collecting dataclasses-json
#   Using cached dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Collecting fsspec>=2023.5.0
#   Downloading fsspec-2024.12.0-py3-none-any.whl (183 kB)
#      |████████████████████████████████| 183 kB 7.1 MB/s eta 0:00:01
# Collecting wrapt
#   Downloading wrapt-1.17.0-cp310-cp310-macosx_11_0_arm64.whl (38 kB)
# Collecting httpx
#   Downloading httpx-0.28.1-py3-none-any.whl (73 kB)
#      |████████████████████████████████| 73 kB 6.5 MB/s eta 0:00:011
# Collecting tiktoken>=0.3.3
#   Downloading tiktoken-0.8.0-cp310-cp310-macosx_11_0_arm64.whl (982 kB)
#      |████████████████████████████████| 982 kB 9.2 MB/s eta 0:00:01
# Collecting tenacity!=8.4.0,<10.0.0,>=8.2.0
#   Using cached tenacity-9.0.0-py3-none-any.whl (28 kB)
# Collecting SQLAlchemy[asyncio]>=1.4.49
#   Downloading SQLAlchemy-2.0.36-cp310-cp310-macosx_11_0_arm64.whl (2.1 MB)
#      |████████████████████████████████| 2.1 MB 5.9 MB/s eta 0:00:01
# Collecting multidict<7.0,>=4.5
#   Using cached multidict-6.1.0-cp310-cp310-macosx_11_0_arm64.whl (29 kB)
# Collecting propcache>=0.2.0
#   Downloading propcache-0.2.1-cp310-cp310-macosx_11_0_arm64.whl (45 kB)
#      |████████████████████████████████| 45 kB 5.9 MB/s eta 0:00:01
# Collecting attrs>=17.3.0
#   Downloading attrs-24.3.0-py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 6.9 MB/s  eta 0:00:01
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.2-py2.py3-none-any.whl (7.6 kB)
# Collecting aiohappyeyeballs>=2.3.0
#   Downloading aiohappyeyeballs-2.4.4-py3-none-any.whl (14 kB)
# Collecting async-timeout<6.0,>=4.0
#   Downloading async_timeout-5.0.1-py3-none-any.whl (6.2 kB)
# Collecting yarl<2.0,>=1.17.0
#   Downloading yarl-1.18.3-cp310-cp310-macosx_11_0_arm64.whl (92 kB)
#      |████████████████████████████████| 92 kB 128 kB/s  eta 0:00:01
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.5.0-cp310-cp310-macosx_11_0_arm64.whl (52 kB)
#      |████████████████████████████████| 52 kB 4.8 MB/s  eta 0:00:01
# Collecting regex>=2021.8.3
#   Downloading regex-2024.11.6-cp310-cp310-macosx_11_0_arm64.whl (284 kB)
#      |████████████████████████████████| 284 kB 700 kB/s eta 0:00:01
# Collecting click
#   Downloading click-8.1.8-py3-none-any.whl (98 kB)
#      |████████████████████████████████| 98 kB 673 kB/s eta 0:00:01
# Collecting joblib
#   Using cached joblib-1.4.2-py3-none-any.whl (301 kB)
# Collecting annotated-types>=0.6.0
#   Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Collecting pydantic-core==2.27.2
#   Downloading pydantic_core-2.27.2-cp310-cp310-macosx_11_0_arm64.whl (1.8 MB)
#      |████████████████████████████████| 1.8 MB 4.4 MB/s eta 0:00:01
# Collecting idna<4,>=2.5
#   Using cached idna-3.10-py3-none-any.whl (70 kB)
# Collecting charset-normalizer<4,>=2
#   Downloading charset_normalizer-3.4.1-cp310-cp310-macosx_10_9_universal2.whl (198 kB)
#      |████████████████████████████████| 198 kB 8.8 MB/s eta 0:00:01
# Collecting urllib3<3,>=1.21.1
#   Downloading urllib3-2.3.0-py3-none-any.whl (128 kB)
#      |████████████████████████████████| 128 kB 9.5 MB/s eta 0:00:01
# Collecting certifi>=2017.4.17
#   Downloading certifi-2024.12.14-py3-none-any.whl (164 kB)
#      |████████████████████████████████| 164 kB 10.0 MB/s eta 0:00:01
# Collecting greenlet!=0.4.17
#   Downloading greenlet-3.1.1-cp310-cp310-macosx_11_0_universal2.whl (271 kB)
#      |████████████████████████████████| 271 kB 8.2 MB/s eta 0:00:01
# Collecting mypy-extensions>=0.3.0
#   Using cached mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Collecting marshmallow<4.0.0,>=3.18.0
#   Downloading marshmallow-3.25.0-py3-none-any.whl (49 kB)
#      |████████████████████████████████| 49 kB 15.4 MB/s eta 0:00:01
# Requirement already satisfied: packaging>=17.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core) (24.2)
# Collecting httpcore==1.*
#   Downloading httpcore-1.0.7-py3-none-any.whl (78 kB)
#      |████████████████████████████████| 78 kB 7.6 MB/s eta 0:00:011
# Collecting anyio
#   Downloading anyio-4.8.0-py3-none-any.whl (96 kB)
#      |████████████████████████████████| 96 kB 6.2 MB/s eta 0:00:011
# Collecting h11<0.15,>=0.13
#   Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from anyio->httpx->llama-index-core) (1.2.2)
# Collecting sniffio>=1.1
#   Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Installing collected packages: urllib3, sniffio, propcache, mypy-extensions, multidict, idna, h11, frozenlist, charset-normalizer, certifi, yarl, wrapt, typing-inspect, tqdm, SQLAlchemy, requests, regex, pydantic-core, marshmallow, joblib, httpcore, greenlet, click, attrs, async-timeout, anyio, annotated-types, aiosignal, aiohappyeyeballs, tiktoken, tenacity, PyYAML, pydantic, pillow, numpy, nltk, networkx, httpx, fsspec, filetype, dirtyjson, deprecated, dataclasses-json, aiohttp, llama-index-core
# Successfully installed PyYAML-6.0.2 SQLAlchemy-2.0.36 aiohappyeyeballs-2.4.4 aiohttp-3.11.11 aiosignal-1.3.2 annotated-types-0.7.0 anyio-4.8.0 async-timeout-5.0.1 attrs-24.3.0 certifi-2024.12.14 charset-normalizer-3.4.1 click-8.1.8 dataclasses-json-0.6.7 deprecated-1.2.15 dirtyjson-1.0.8 filetype-1.2.0 frozenlist-1.5.0 fsspec-2024.12.0 greenlet-3.1.1 h11-0.14.0 httpcore-1.0.7 httpx-0.28.1 idna-3.10 joblib-1.4.2 llama-index-core-0.12.10.post1 marshmallow-3.25.0 multidict-6.1.0 mypy-extensions-1.0.0 networkx-3.4.2 nltk-3.9.1 numpy-2.2.1 pillow-11.1.0 propcache-0.2.1 pydantic-2.10.5 pydantic-core-2.27.2 regex-2024.11.6 requests-2.32.3 sniffio-1.3.1 tenacity-9.0.0 tiktoken-0.8.0 tqdm-4.67.1 typing-inspect-0.9.0 urllib3-2.3.0 wrapt-1.17.0 yarl-1.18.3
# WARNING: You are using pip version 21.2.3; however, version 24.3.1 is available.
# You should consider upgrading via the '/Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Collecting llama-index-agent-openai
#   Downloading llama_index_agent_openai-0.4.1-py3-none-any.whl (13 kB)
# Collecting openai>=1.14.0
#   Downloading openai-1.59.5-py3-none-any.whl (454 kB)
#      |████████████████████████████████| 454 kB 32 kB/s eta 0:00:01
# Collecting llama-index-llms-openai<0.4.0,>=0.3.0
#   Downloading llama_index_llms_openai-0.3.13-py3-none-any.whl (14 kB)
# Requirement already satisfied: llama-index-core<0.13.0,>=0.12.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-agent-openai) (0.12.10.post1)
# Requirement already satisfied: typing-inspect>=0.8.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-agent-openai) (0.9.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-agent-openai) (2024.12.0)
# Requirement already satisfied: httpx in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-agent-openai) (0.28.1)
# Requirement already satisfied: nltk>3.8.1 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-agent-openai) (3.9.1)
# Requirement already satisfied: wrapt in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-agent-openai) (1.17.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-agent-openai) (4.12.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-agent-openai) (3.11.11)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-agent-openai) (9.0.0)
# Requirement already satisfied: deprecated>=1.2.9.3 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-agent-openai) (1.2.15)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-agent-openai) (4.67.1)
# Requirement already satisfied: PyYAML>=6.0.1 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-agent-openai) (6.0.2)
# Requirement already satisfied: tiktoken>=0.3.3 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-agent-openai) (0.8.0)
# Requirement already satisfied: SQLAlchemy[asyncio]>=1.4.49 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-agent-openai) (2.0.36)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-agent-openai) (1.2.0)
# Requirement already satisfied: pydantic>=2.8.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-agent-openai) (2.10.5)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-agent-openai) (1.6.0)
# Requirement already satisfied: pillow>=9.0.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-agent-openai) (11.1.0)
# Requirement already satisfied: requests>=2.31.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-agent-openai) (2.32.3)
# Requirement already satisfied: dataclasses-json in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-agent-openai) (0.6.7)
# Requirement already satisfied: networkx>=3.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-agent-openai) (3.4.2)
# Requirement already satisfied: numpy in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-agent-openai) (2.2.1)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-agent-openai) (1.0.8)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-agent-openai) (2.4.4)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-agent-openai) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-agent-openai) (1.18.3)
# Requirement already satisfied: propcache>=0.2.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-agent-openai) (0.2.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-agent-openai) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-agent-openai) (24.3.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-agent-openai) (5.0.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-agent-openai) (1.5.0)
# Requirement already satisfied: click in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-agent-openai) (8.1.8)
# Requirement already satisfied: joblib in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-agent-openai) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-agent-openai) (2024.11.6)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from openai>=1.14.0->llama-index-agent-openai) (4.8.0)
# Collecting distro<2,>=1.7.0
#   Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Collecting jiter<1,>=0.4.0
#   Downloading jiter-0.8.2-cp310-cp310-macosx_11_0_arm64.whl (311 kB)
#      |████████████████████████████████| 311 kB 3.1 MB/s eta 0:00:01
# Requirement already satisfied: sniffio in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from openai>=1.14.0->llama-index-agent-openai) (1.3.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai>=1.14.0->llama-index-agent-openai) (1.2.2)
# Requirement already satisfied: idna>=2.8 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai>=1.14.0->llama-index-agent-openai) (3.10)
# Requirement already satisfied: httpcore==1.* in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-agent-openai) (1.0.7)
# Requirement already satisfied: certifi in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-agent-openai) (2024.12.14)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from httpcore==1.*->httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-agent-openai) (0.14.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-agent-openai) (2.27.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-agent-openai) (0.7.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-agent-openai) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-agent-openai) (2.3.0)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.0->llama-index-agent-openai) (3.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-agent-openai) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from dataclasses-json->llama-index-core<0.13.0,>=0.12.0->llama-index-agent-openai) (3.25.0)
# Requirement already satisfied: packaging>=17.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.13.0,>=0.12.0->llama-index-agent-openai) (24.2)
# Installing collected packages: jiter, distro, openai, llama-index-llms-openai, llama-index-agent-openai
# Successfully installed distro-1.9.0 jiter-0.8.2 llama-index-agent-openai-0.4.1 llama-index-llms-openai-0.3.13 openai-1.59.5
# WARNING: You are using pip version 21.2.3; however, version 24.3.1 is available.
# You should consider upgrading via the '/Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Collecting llama-index-readers-file
#   Downloading llama_index_readers_file-0.4.2-py3-none-any.whl (38 kB)
# Collecting striprtf<0.0.27,>=0.0.26
#   Using cached striprtf-0.0.26-py3-none-any.whl (6.9 kB)
# Requirement already satisfied: llama-index-core<0.13.0,>=0.12.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-readers-file) (0.12.10.post1)
# Collecting pypdf<6.0.0,>=5.1.0
#   Downloading pypdf-5.1.0-py3-none-any.whl (297 kB)
#      |████████████████████████████████| 297 kB 500 kB/s eta 0:00:01
# Collecting beautifulsoup4<5.0.0,>=4.12.3
#   Using cached beautifulsoup4-4.12.3-py3-none-any.whl (147 kB)
# Collecting pandas
#   Using cached pandas-2.2.3-cp310-cp310-macosx_11_0_arm64.whl (11.3 MB)
# Collecting soupsieve>1.2
#   Using cached soupsieve-2.6-py3-none-any.whl (36 kB)
# Requirement already satisfied: typing-extensions>=4.5.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (4.12.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (9.0.0)
# Requirement already satisfied: tiktoken>=0.3.3 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (0.8.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (0.9.0)
# Requirement already satisfied: wrapt in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (1.17.0)
# Requirement already satisfied: nltk>3.8.1 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (3.9.1)
# Requirement already satisfied: PyYAML>=6.0.1 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (6.0.2)
# Requirement already satisfied: pillow>=9.0.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (11.1.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (2024.12.0)
# Requirement already satisfied: httpx in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (0.28.1)
# Requirement already satisfied: SQLAlchemy[asyncio]>=1.4.49 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (2.0.36)
# Requirement already satisfied: pydantic>=2.8.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (2.10.5)
# Requirement already satisfied: numpy in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (2.2.1)
# Requirement already satisfied: deprecated>=1.2.9.3 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (1.2.15)
# Requirement already satisfied: dataclasses-json in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (0.6.7)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (1.6.0)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (1.0.8)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (3.11.11)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (1.2.0)
# Requirement already satisfied: networkx>=3.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (3.4.2)
# Requirement already satisfied: requests>=2.31.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (2.32.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (4.67.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (2.4.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (1.5.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (24.3.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (1.3.2)
# Requirement already satisfied: propcache>=0.2.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (1.18.3)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (5.0.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (6.1.0)
# Requirement already satisfied: click in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (8.1.8)
# Requirement already satisfied: joblib in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (2024.11.6)
# Requirement already satisfied: pydantic-core==2.27.2 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (2.27.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (0.7.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (2024.12.14)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (3.4.1)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (3.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from dataclasses-json->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (3.25.0)
# Requirement already satisfied: packaging>=17.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (24.2)
# Requirement already satisfied: anyio in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (4.8.0)
# Requirement already satisfied: httpcore==1.* in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from httpcore==1.*->httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (0.14.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from anyio->httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (1.3.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from anyio->httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (1.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from pandas->llama-index-readers-file) (2.9.0.post0)
# Collecting pytz>=2020.1
#   Using cached pytz-2024.2-py2.py3-none-any.whl (508 kB)
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='pypi.org', port=443): Read timed out. (read timeout=15)")': /simple/tzdata/
# Collecting tzdata>=2022.7
#   Using cached tzdata-2024.2-py2.py3-none-any.whl (346 kB)
# Requirement already satisfied: six>=1.5 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->llama-index-readers-file) (1.17.0)
# Installing collected packages: tzdata, soupsieve, pytz, striprtf, pypdf, pandas, beautifulsoup4, llama-index-readers-file
# Successfully installed beautifulsoup4-4.12.3 llama-index-readers-file-0.4.2 pandas-2.2.3 pypdf-5.1.0 pytz-2024.2 soupsieve-2.6 striprtf-0.0.26 tzdata-2024.2
# WARNING: You are using pip version 21.2.3; however, version 24.3.1 is available.
# You should consider upgrading via the '/Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Collecting llama-index-postprocessor-cohere-rerank
#   Downloading llama_index_postprocessor_cohere_rerank-0.3.0-py3-none-any.whl (2.9 kB)
# Collecting cohere<6.0.0,>=5.1.1
#   Downloading cohere-5.13.6-py3-none-any.whl (250 kB)
#      |████████████████████████████████| 250 kB 987 kB/s eta 0:00:01
# Requirement already satisfied: llama-index-core<0.13.0,>=0.12.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-postprocessor-cohere-rerank) (0.12.10.post1)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from cohere<6.0.0,>=5.1.1->llama-index-postprocessor-cohere-rerank) (2.32.3)
# Collecting fastavro<2.0.0,>=1.9.4
#   Downloading fastavro-1.10.0-cp310-cp310-macosx_10_9_universal2.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 7.6 MB/s eta 0:00:01
# Collecting httpx-sse==0.4.0
#   Using cached httpx_sse-0.4.0-py3-none-any.whl (7.8 kB)
# Requirement already satisfied: httpx>=0.21.2 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from cohere<6.0.0,>=5.1.1->llama-index-postprocessor-cohere-rerank) (0.28.1)
# Collecting tokenizers<1,>=0.15
#   Downloading tokenizers-0.21.0-cp39-abi3-macosx_11_0_arm64.whl (2.6 MB)
#      |████████████████████████████████| 2.6 MB 6.8 MB/s eta 0:00:01
# Requirement already satisfied: pydantic-core<3.0.0,>=2.18.2 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from cohere<6.0.0,>=5.1.1->llama-index-postprocessor-cohere-rerank) (2.27.2)
# Collecting types-requests<3.0.0,>=2.0.0
#   Using cached types_requests-2.32.0.20241016-py3-none-any.whl (15 kB)
# Collecting parameterized<0.10.0,>=0.9.0
#   Using cached parameterized-0.9.0-py2.py3-none-any.whl (20 kB)
# Requirement already satisfied: pydantic>=1.9.2 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from cohere<6.0.0,>=5.1.1->llama-index-postprocessor-cohere-rerank) (2.10.5)
# Requirement already satisfied: typing_extensions>=4.0.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from cohere<6.0.0,>=5.1.1->llama-index-postprocessor-cohere-rerank) (4.12.2)
# Requirement already satisfied: anyio in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from httpx>=0.21.2->cohere<6.0.0,>=5.1.1->llama-index-postprocessor-cohere-rerank) (4.8.0)
# Requirement already satisfied: certifi in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from httpx>=0.21.2->cohere<6.0.0,>=5.1.1->llama-index-postprocessor-cohere-rerank) (2024.12.14)
# Requirement already satisfied: idna in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from httpx>=0.21.2->cohere<6.0.0,>=5.1.1->llama-index-postprocessor-cohere-rerank) (3.10)
# Requirement already satisfied: httpcore==1.* in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from httpx>=0.21.2->cohere<6.0.0,>=5.1.1->llama-index-postprocessor-cohere-rerank) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from httpcore==1.*->httpx>=0.21.2->cohere<6.0.0,>=5.1.1->llama-index-postprocessor-cohere-rerank) (0.14.0)
# Requirement already satisfied: wrapt in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-postprocessor-cohere-rerank) (1.17.0)
# Requirement already satisfied: SQLAlchemy[asyncio]>=1.4.49 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-postprocessor-cohere-rerank) (2.0.36)
# Requirement already satisfied: pillow>=9.0.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-postprocessor-cohere-rerank) (11.1.0)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-postprocessor-cohere-rerank) (1.0.8)
# Requirement already satisfied: PyYAML>=6.0.1 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-postprocessor-cohere-rerank) (6.0.2)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-postprocessor-cohere-rerank) (1.2.0)
# Requirement already satisfied: numpy in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-postprocessor-cohere-rerank) (2.2.1)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-postprocessor-cohere-rerank) (9.0.0)
# Requirement already satisfied: nltk>3.8.1 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-postprocessor-cohere-rerank) (3.9.1)
# Requirement already satisfied: typing-inspect>=0.8.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-postprocessor-cohere-rerank) (0.9.0)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-postprocessor-cohere-rerank) (1.6.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-postprocessor-cohere-rerank) (2024.12.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-postprocessor-cohere-rerank) (4.67.1)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-postprocessor-cohere-rerank) (3.11.11)
# Requirement already satisfied: networkx>=3.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-postprocessor-cohere-rerank) (3.4.2)
# Requirement already satisfied: dataclasses-json in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-postprocessor-cohere-rerank) (0.6.7)
# Requirement already satisfied: tiktoken>=0.3.3 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-postprocessor-cohere-rerank) (0.8.0)
# Requirement already satisfied: deprecated>=1.2.9.3 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-postprocessor-cohere-rerank) (1.2.15)
# Requirement already satisfied: propcache>=0.2.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-postprocessor-cohere-rerank) (0.2.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-postprocessor-cohere-rerank) (24.3.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-postprocessor-cohere-rerank) (5.0.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-postprocessor-cohere-rerank) (1.3.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-postprocessor-cohere-rerank) (6.1.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-postprocessor-cohere-rerank) (2.4.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-postprocessor-cohere-rerank) (1.5.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-postprocessor-cohere-rerank) (1.18.3)
# Requirement already satisfied: regex>=2021.8.3 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-postprocessor-cohere-rerank) (2024.11.6)
# Requirement already satisfied: joblib in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-postprocessor-cohere-rerank) (1.4.2)
# Requirement already satisfied: click in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-postprocessor-cohere-rerank) (8.1.8)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from pydantic>=1.9.2->cohere<6.0.0,>=5.1.1->llama-index-postprocessor-cohere-rerank) (0.7.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from requests<3.0.0,>=2.0.0->cohere<6.0.0,>=5.1.1->llama-index-postprocessor-cohere-rerank) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from requests<3.0.0,>=2.0.0->cohere<6.0.0,>=5.1.1->llama-index-postprocessor-cohere-rerank) (2.3.0)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.0->llama-index-postprocessor-cohere-rerank) (3.1.1)
# Collecting huggingface-hub<1.0,>=0.16.4
#   Downloading huggingface_hub-0.27.1-py3-none-any.whl (450 kB)
#      |████████████████████████████████| 450 kB 14.2 MB/s eta 0:00:01
# Collecting filelock
#   Using cached filelock-3.16.1-py3-none-any.whl (16 kB)
# Requirement already satisfied: packaging>=20.9 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<1,>=0.15->cohere<6.0.0,>=5.1.1->llama-index-postprocessor-cohere-rerank) (24.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-postprocessor-cohere-rerank) (1.0.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from anyio->httpx>=0.21.2->cohere<6.0.0,>=5.1.1->llama-index-postprocessor-cohere-rerank) (1.2.2)
# Requirement already satisfied: sniffio>=1.1 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from anyio->httpx>=0.21.2->cohere<6.0.0,>=5.1.1->llama-index-postprocessor-cohere-rerank) (1.3.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from dataclasses-json->llama-index-core<0.13.0,>=0.12.0->llama-index-postprocessor-cohere-rerank) (3.25.0)
# Installing collected packages: filelock, huggingface-hub, types-requests, tokenizers, parameterized, httpx-sse, fastavro, cohere, llama-index-postprocessor-cohere-rerank
# Successfully installed cohere-5.13.6 fastavro-1.10.0 filelock-3.16.1 httpx-sse-0.4.0 huggingface-hub-0.27.1 llama-index-postprocessor-cohere-rerank-0.3.0 parameterized-0.9.0 tokenizers-0.21.0 types-requests-2.32.0.20241016
# WARNING: You are using pip version 21.2.3; however, version 24.3.1 is available.
# You should consider upgrading via the '/Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: llama-index-llms-openai in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (0.3.13)
# Requirement already satisfied: openai<2.0.0,>=1.58.1 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-llms-openai) (1.59.5)
# Requirement already satisfied: llama-index-core<0.13.0,>=0.12.4 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-llms-openai) (0.12.10.post1)
# ...
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.58.1->llama-index-llms-openai) (1.2.2)
# Requirement already satisfied: idna>=2.8 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.58.1->llama-index-llms-openai) (3.10)
# Requirement already satisfied: certifi in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from httpx->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-openai) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from httpx->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-openai) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from httpcore==1.*->httpx->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-openai) (0.14.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-openai) (2.27.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-openai) (0.7.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-openai) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-openai) (2.3.0)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-openai) (3.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-openai) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from dataclasses-json->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-openai) (3.25.0)
# Requirement already satisfied: packaging>=17.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-openai) (24.2)
# WARNING: You are using pip version 21.2.3; however, version 24.3.1 is available.
# You should consider upgrading via the '/Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Collecting llama-index-embeddings-openai
#   Downloading llama_index_embeddings_openai-0.3.1-py3-none-any.whl (6.2 kB)
# Requirement already satisfied: llama-index-core<0.13.0,>=0.12.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-embeddings-openai) (0.12.10.post1)
# Requirement already satisfied: openai>=1.1.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-embeddings-openai) (1.59.5)
# Requirement already satisfied: typing-inspect>=0.8.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (0.9.0)
# Requirement already satisfied: httpx in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (0.28.1)
# Requirement already satisfied: tiktoken>=0.3.3 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (0.8.0)
# Requirement already satisfied: PyYAML>=6.0.1 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (6.0.2)
# Requirement already satisfied: SQLAlchemy[asyncio]>=1.4.49 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (2.0.36)
# Requirement already satisfied: numpy in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (2.2.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (2024.12.0)
# Requirement already satisfied: requests>=2.31.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (2.32.3)
# Requirement already satisfied: typing-extensions>=4.5.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (4.12.2)
# Requirement already satisfied: pillow>=9.0.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (11.1.0)
# Requirement already satisfied: networkx>=3.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (3.4.2)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (1.6.0)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (1.2.0)
# Requirement already satisfied: dataclasses-json in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (0.6.7)
# Requirement already satisfied: pydantic>=2.8.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (2.10.5)
# Requirement already satisfied: deprecated>=1.2.9.3 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (1.2.15)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (9.0.0)
# Requirement already satisfied: nltk>3.8.1 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (3.9.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (4.67.1)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (1.0.8)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (3.11.11)
# Requirement already satisfied: wrapt in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (1.17.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (0.2.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (1.5.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (2.4.4)
# Requirement already satisfied: attrs>=17.3.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (24.3.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (6.1.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (1.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (1.18.3)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (5.0.1)
# Requirement already satisfied: regex>=2021.8.3 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (2024.11.6)
# Requirement already satisfied: joblib in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (1.4.2)
# Requirement already satisfied: click in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (8.1.8)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from openai>=1.1.0->llama-index-embeddings-openai) (0.8.2)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from openai>=1.1.0->llama-index-embeddings-openai) (1.9.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from openai>=1.1.0->llama-index-embeddings-openai) (4.8.0)
# Requirement already satisfied: sniffio in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from openai>=1.1.0->llama-index-embeddings-openai) (1.3.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai>=1.1.0->llama-index-embeddings-openai) (1.2.2)
# Requirement already satisfied: idna>=2.8 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai>=1.1.0->llama-index-embeddings-openai) (3.10)
# Requirement already satisfied: certifi in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from httpcore==1.*->httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (2.3.0)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (3.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from dataclasses-json->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (3.25.0)
# Requirement already satisfied: packaging>=17.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (24.2)
# Installing collected packages: llama-index-embeddings-openai
# Successfully installed llama-index-embeddings-openai-0.3.1
# WARNING: You are using pip version 21.2.3; however, version 24.3.1 is available.
# You should consider upgrading via the '/Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# zsh:1: no matches found: unstructured[html]
# Note: you may need to restart the kernel to use updated packages.

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Setup and Download Data
#
# In this section, we'll load in the LlamaIndex documentation.

# %%
domain = "docs.llamaindex.ai"
docs_url = "https://docs.llamaindex.ai/en/latest/"
# !wget -e robots=off --recursive --no-clobber --page-requisites --html-extension --convert-links --restrict-file-names=windows --domains {domain} --no-parent {docs_url}
# Out:
# Both --no-clobber and --convert-links were specified, only --convert-links will be used.
# --2025-01-09 14:36:43--  https://docs.llamaindex.ai/en/latest/
# Resolving docs.llamaindex.ai (docs.llamaindex.ai)... 2606:4700::6812:a3, 2606:4700::6812:1a3, 104.18.1.163, ...
# Connecting to docs.llamaindex.ai (docs.llamaindex.ai)|2606:4700::6812:a3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 621832 (607K) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/index.html’
#
# docs.llamaindex.ai/ 100%[===================>] 607.26K  --.-KB/s    in 0.1s
#
# 2025-01-09 14:36:44 (4.35 MB/s) - ‘docs.llamaindex.ai/en/latest/index.html’ saved [621832/621832]
#
# --2025-01-09 14:36:44--  https://docs.llamaindex.ai/en/latest/getting_started/concepts/
# Reusing existing connection to [docs.llamaindex.ai]:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 621415 (607K) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/getting_started/concepts/index.html’
#
# docs.llamaindex.ai/ 100%[===================>] 606.85K  --.-KB/s    in 0.06s
#
# 2025-01-09 14:36:44 (10.7 MB/s) - ‘docs.llamaindex.ai/en/latest/getting_started/concepts/index.html’ saved [621415/621415]
#
# --2025-01-09 14:36:44--  https://docs.llamaindex.ai/en/latest/_static/assets/LlamaLogoBrowserTab.png
# Reusing existing connection to [docs.llamaindex.ai]:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 37263 (36K) [image/png]
# Saving to: ‘docs.llamaindex.ai/en/latest/_static/assets/LlamaLogoBrowserTab.png’
#
# docs.llamaindex.ai/ 100%[===================>]  36.39K  --.-KB/s    in 0s
#
# 2025-01-09 14:36:45 (116 MB/s) - ‘docs.llamaindex.ai/en/latest/_static/assets/LlamaLogoBrowserTab.png’ saved [37263/37263]
#
# --2025-01-09 14:36:45--  https://docs.llamaindex.ai/en/latest/assets/stylesheets/main.6f8fc17f.min.css
# Reusing existing connection to [docs.llamaindex.ai]:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/css]
# Saving to: ‘docs.llamaindex.ai/en/latest/assets/stylesheets/main.6f8fc17f.min.css’
#
# docs.llamaindex.ai/     [ <=>                ] 128.59K  --.-KB/s    in 0.01s
#
# 2025-01-09 14:36:45 (11.7 MB/s) - ‘docs.llamaindex.ai/en/latest/assets/stylesheets/main.6f8fc17f.min.css’ saved [131681]
#
# --2025-01-09 14:36:45--  https://docs.llamaindex.ai/en/latest/assets/stylesheets/palette.06af60db.min.css
# Reusing existing connection to [docs.llamaindex.ai]:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/css]
# Saving to: ‘docs.llamaindex.ai/en/latest/assets/stylesheets/palette.06af60db.min.css’
#
# docs.llamaindex.ai/     [ <=>                ]  12.23K  --.-KB/s    in 0s
#
# 2025-01-09 14:36:45 (2.33 GB/s) - ‘docs.llamaindex.ai/en/latest/assets/stylesheets/palette.06af60db.min.css’ saved [12522]
#
# --2025-01-09 14:36:45--  https://docs.llamaindex.ai/en/latest/assets/_mkdocstrings.css
# Reusing existing connection to [docs.llamaindex.ai]:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/css]
# Saving to: ‘docs.llamaindex.ai/en/latest/assets/_mkdocstrings.css’
#
# docs.llamaindex.ai/     [ <=>                ]   3.31K  --.-KB/s    in 0s
#
# 2025-01-09 14:36:45 (1.05 GB/s) - ‘docs.llamaindex.ai/en/latest/assets/_mkdocstrings.css’ saved [3386]
#
# --2025-01-09 14:36:45--  https://docs.llamaindex.ai/en/latest/css/style.css
# Reusing existing connection to [docs.llamaindex.ai]:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/css]
# Saving to: ‘docs.llamaindex.ai/en/latest/css/style.css’
#
# docs.llamaindex.ai/     [ <=>                ]   1.04K  --.-KB/s    in 0s
#
# 2025-01-09 14:36:45 (1011 MB/s) - ‘docs.llamaindex.ai/en/latest/css/style.css’ saved [1060]
#
# --2025-01-09 14:36:45--  https://docs.llamaindex.ai/en/latest/css/algolia.css
# Reusing existing connection to [docs.llamaindex.ai]:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/css]
# Saving to: ‘docs.llamaindex.ai/en/latest/css/algolia.css’
#
# docs.llamaindex.ai/     [ <=>                ]  16.06K  --.-KB/s    in 0s
#
# 2025-01-09 14:36:45 (245 MB/s) - ‘docs.llamaindex.ai/en/latest/css/algolia.css’ saved [16445]
#
# --2025-01-09 14:36:45--  https://docs.llamaindex.ai/_/static/javascript/readthedocs-addons.js
# Reusing existing connection to [docs.llamaindex.ai]:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/javascript]
# Saving to: ‘docs.llamaindex.ai/_/static/javascript/readthedocs-addons.js’
#
# docs.llamaindex.ai/     [ <=>                ] 427.88K  --.-KB/s    in 0.04s
#
# 2025-01-09 14:36:45 (10.4 MB/s) - ‘docs.llamaindex.ai/_/static/javascript/readthedocs-addons.js’ saved [438153]
#
# --2025-01-09 14:36:45--  https://docs.llamaindex.ai/en/latest/_static/assets/LlamaSquareBlack.svg
# Reusing existing connection to [docs.llamaindex.ai]:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [image/svg+xml]
# Saving to: ‘docs.llamaindex.ai/en/latest/_static/assets/LlamaSquareBlack.svg’
#
# docs.llamaindex.ai/     [ <=>                ]   6.28K  --.-KB/s    in 0s
#
# 2025-01-09 14:36:45 (613 MB/s) - ‘docs.llamaindex.ai/en/latest/_static/assets/LlamaSquareBlack.svg’ saved [6429]
#
# --2025-01-09 14:36:45--  https://docs.llamaindex.ai/en/latest/understanding/
# Reusing existing connection to [docs.llamaindex.ai]:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 616466 (602K) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/understanding/index.html’
#
# docs.llamaindex.ai/ 100%[===================>] 602.02K  --.-KB/s    in 0.05s
#
# 2025-01-09 14:36:45 (10.7 MB/s) - ‘docs.llamaindex.ai/en/latest/understanding/index.html’ saved [616466/616466]
#
# --2025-01-09 14:36:45--  https://docs.llamaindex.ai/en/latest/use_cases/
# Reusing existing connection to [docs.llamaindex.ai]:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 610736 (596K) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/use_cases/index.html’
#
# docs.llamaindex.ai/ 100%[===================>] 596.42K  --.-KB/s    in 0.06s
#
# 2025-01-09 14:36:45 (10.6 MB/s) - ‘docs.llamaindex.ai/en/latest/use_cases/index.html’ saved [610736/610736]
#
# --2025-01-09 14:36:45--  https://docs.llamaindex.ai/en/latest/examples/
# Reusing existing connection to [docs.llamaindex.ai]:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 603807 (590K) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/index.html’
#
# docs.llamaindex.ai/ 100%[===================>] 589.66K  --.-KB/s    in 0.07s
#
# 2025-01-09 14:36:46 (8.56 MB/s) - ‘docs.llamaindex.ai/en/latest/examples/index.html’ saved [603807/603807]
#
# --2025-01-09 14:36:46--  https://docs.llamaindex.ai/en/latest/module_guides/
# Reusing existing connection to [docs.llamaindex.ai]:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 609448 (595K) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/module_guides/index.html’
#
# docs.llamaindex.ai/ 100%[===================>] 595.16K  --.-KB/s    in 0.06s
#
# 2025-01-09 14:36:46 (9.00 MB/s) - ‘docs.llamaindex.ai/en/latest/module_guides/index.html’ saved [609448/609448]
#
# --2025-01-09 14:36:46--  https://docs.llamaindex.ai/en/latest/optimizing/production_rag/
# Reusing existing connection to [docs.llamaindex.ai]:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 632915 (618K) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/optimizing/production_rag/index.html’
#
# docs.llamaindex.ai/ 100%[===================>] 618.08K  --.-KB/s    in 0.07s
#
# 2025-01-09 14:36:46 (9.01 MB/s) - ‘docs.llamaindex.ai/en/latest/optimizing/production_rag/index.html’ saved [632915/632915]
#
# --2025-01-09 14:36:46--  https://docs.llamaindex.ai/en/latest/api_reference/
# Reusing existing connection to [docs.llamaindex.ai]:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 597338 (583K) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/index.html’
#
# docs.llamaindex.ai/ 100%[===================>] 583.34K  --.-KB/s    in 0.05s
#
# 2025-01-09 14:36:47 (10.7 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/index.html’ saved [597338/597338]
#
# --2025-01-09 14:36:47--  https://docs.llamaindex.ai/en/latest/community/integrations/
# Reusing existing connection to [docs.llamaindex.ai]:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 623236 (609K) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/community/integrations/index.html’
#
# docs.llamaindex.ai/ 100%[===================>] 608.63K  --.-KB/s    in 0.04s
#
# 2025-01-09 14:36:48 (13.4 MB/s) - ‘docs.llamaindex.ai/en/latest/community/integrations/index.html’ saved [623236/623236]
#
# --2025-01-09 14:36:48--  https://docs.llamaindex.ai/en/latest/llama_cloud/
# Reusing existing connection to [docs.llamaindex.ai]:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 613345 (599K) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/llama_cloud/index.html’
#
# docs.llamaindex.ai/ 100%[===================>] 598.97K  --.-KB/s    in 0.05s
#
# 2025-01-09 14:36:48 (12.7 MB/s) - ‘docs.llamaindex.ai/en/latest/llama_cloud/index.html’ saved [613345/613345]
#
# --2025-01-09 14:36:48--  https://docs.llamaindex.ai/en/latest/getting_started/installation/
# Reusing existing connection to [docs.llamaindex.ai]:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 622517 (608K) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/getting_started/installation/index.html’
#
# docs.llamaindex.ai/ 100%[===================>] 607.93K  --.-KB/s    in 0.05s
#
# 2025-01-09 14:36:48 (12.8 MB/s) - ‘docs.llamaindex.ai/en/latest/getting_started/installation/index.html’ saved [622517/622517]
#
# --2025-01-09 14:36:48--  https://docs.llamaindex.ai/en/latest/getting_started/reading/
# Reusing existing connection to [docs.llamaindex.ai]:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 620300 (606K) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/getting_started/reading/index.html’
#
# docs.llamaindex.ai/ 100%[===================>] 605.76K  --.-KB/s    in 0.06s
#
# 2025-01-09 14:36:49 (10.1 MB/s) - ‘docs.llamaindex.ai/en/latest/getting_started/reading/index.html’ saved [620300/620300]
#
# --2025-01-09 14:36:49--  https://docs.llamaindex.ai/en/latest/getting_started/starter_example/
# Reusing existing connection to [docs.llamaindex.ai]:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 628877 (614K) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/getting_started/starter_example/index.html’
#
# docs.llamaindex.ai/ 100%[===================>] 614.14K  --.-KB/s    in 0.04s
#
# 2025-01-09 14:36:49 (14.7 MB/s) - ‘docs.llamaindex.ai/en/latest/getting_started/starter_example/index.html’ saved [628877/628877]
#
# --2025-01-09 14:36:49--  https://docs.llamaindex.ai/en/latest/getting_started/starter_example_local/
# Reusing existing connection to [docs.llamaindex.ai]:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 624348 (610K) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/getting_started/starter_example_local/index.html’
#
# docs.llamaindex.ai/ 100%[===================>] 609.71K  --.-KB/s    in 0.05s
#
# 2025-01-09 14:36:50 (11.5 MB/s) - ‘docs.llamaindex.ai/en/latest/getting_started/starter_example_local/index.html’ saved [624348/624348]
#
# --2025-01-09 14:36:50--  https://docs.llamaindex.ai/en/latest/getting_started/discover_llamaindex/
# Reusing existing connection to [docs.llamaindex.ai]:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 621138 (607K) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/getting_started/discover_llamaindex/index.html’
#
# docs.llamaindex.ai/ 100%[===================>] 606.58K  --.-KB/s    in 0.05s
#
# 2025-01-09 14:36:50 (11.0 MB/s) - ‘docs.llamaindex.ai/en/latest/getting_started/discover_llamaindex/index.html’ saved [621138/621138]
#
# --2025-01-09 14:36:51--  https://docs.llamaindex.ai/en/latest/getting_started/customization/
# Reusing existing connection to [docs.llamaindex.ai]:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 636769 (622K) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/getting_started/customization/index.html’
#
# docs.llamaindex.ai/ 100%[===================>] 621.84K  --.-KB/s    in 0.05s
#
# 2025-01-09 14:36:51 (13.0 MB/s) - ‘docs.llamaindex.ai/en/latest/getting_started/customization/index.html’ saved [636769/636769]
#
# --2025-01-09 14:36:51--  https://docs.llamaindex.ai/en/latest/getting_started/starter_tools/
# Reusing existing connection to [docs.llamaindex.ai]:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 620111 (606K) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/getting_started/starter_tools/index.html’
#
# docs.llamaindex.ai/ 100%[===================>] 605.58K  2.16MB/s    in 0.3s
#
# 2025-01-09 14:36:52 (2.16 MB/s) - ‘docs.llamaindex.ai/en/latest/getting_started/starter_tools/index.html’ saved [620111/620111]
#
# --2025-01-09 14:36:52--  https://docs.llamaindex.ai/en/latest/getting_started/starter_tools/rag_cli/
# Reusing existing connection to [docs.llamaindex.ai]:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 644577 (629K) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/getting_started/starter_tools/rag_cli/index.html’
#
# docs.llamaindex.ai/ 100%[===================>] 629.47K  3.61MB/s    in 0.2s
#
# 2025-01-09 14:36:52 (3.61 MB/s) - ‘docs.llamaindex.ai/en/latest/getting_started/starter_tools/rag_cli/index.html’ saved [644577/644577]
#
# --2025-01-09 14:36:52--  https://docs.llamaindex.ai/en/latest/understanding/using_llms/using_llms/
# Reusing existing connection to [docs.llamaindex.ai]:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 628317 (614K) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/understanding/using_llms/using_llms/index.html’
#
# docs.llamaindex.ai/ 100%[===================>] 613.59K  3.36MB/s    in 0.2s
#
# 2025-01-09 14:36:53 (3.36 MB/s) - ‘docs.llamaindex.ai/en/latest/understanding/using_llms/using_llms/index.html’ saved [628317/628317]
#
# --2025-01-09 14:36:53--  https://docs.llamaindex.ai/en/latest/understanding/rag/
# Reusing existing connection to [docs.llamaindex.ai]:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 622159 (608K) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/understanding/rag/index.html’
#
# docs.llamaindex.ai/ 100%[===================>] 607.58K  3.29MB/s    in 0.2s
#
# 2025-01-09 14:36:54 (3.29 MB/s) - ‘docs.llamaindex.ai/en/latest/understanding/rag/index.html’ saved [622159/622159]
#
# --2025-01-09 14:36:54--  https://docs.llamaindex.ai/en/latest/understanding/loading/loading/
# Reusing existing connection to [docs.llamaindex.ai]:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 640536 (626K) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/understanding/loading/loading/index.html’
#
# docs.llamaindex.ai/ 100%[===================>] 625.52K  2.33MB/s    in 0.3s
#
# 2025-01-09 14:36:54 (2.33 MB/s) - ‘docs.llamaindex.ai/en/latest/understanding/loading/loading/index.html’ saved [640536/640536]
#
# --2025-01-09 14:36:54--  https://docs.llamaindex.ai/en/latest/understanding/loading/llamahub/
# Reusing existing connection to [docs.llamaindex.ai]:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 624868 (610K) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/understanding/loading/llamahub/index.html’
#
# docs.llamaindex.ai/ 100%[===================>] 610.22K  1.92MB/s    in 0.3s
#
# 2025-01-09 14:36:55 (1.92 MB/s) - ‘docs.llamaindex.ai/en/latest/understanding/loading/llamahub/index.html’ saved [624868/624868]
#
# --2025-01-09 14:36:55--  https://docs.llamaindex.ai/en/latest/understanding/loading/llamacloud/
# Reusing existing connection to [docs.llamaindex.ai]:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 623379 (609K) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/understanding/loading/llamacloud/index.html’
#
# docs.llamaindex.ai/ 100%[===================>] 608.77K  1.48MB/s    in 0.4s
#
# 2025-01-09 14:36:56 (1.48 MB/s) - ‘docs.llamaindex.ai/en/latest/understanding/loading/llamacloud/index.html’ saved [623379/623379]
#
# --2025-01-09 14:36:56--  https://docs.llamaindex.ai/en/latest/understanding/indexing/indexing/
# Reusing existing connection to [docs.llamaindex.ai]:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 629975 (615K) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/understanding/indexing/indexing/index.html’
#
# docs.llamaindex.ai/ 100%[===================>] 615.21K  1.68MB/s    in 0.4s
#
# 2025-01-09 14:36:57 (1.68 MB/s) - ‘docs.llamaindex.ai/en/latest/understanding/indexing/indexing/index.html’ saved [629975/629975]
#
# --2025-01-09 14:36:57--  https://docs.llamaindex.ai/en/latest/understanding/storing/storing/
# Reusing existing connection to [docs.llamaindex.ai]:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 634354 (619K) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/understanding/storing/storing/index.html’
#
# docs.llamaindex.ai/ 100%[===================>] 619.49K  2.62MB/s    in 0.2s
#
# 2025-01-09 14:36:58 (2.62 MB/s) - ‘docs.llamaindex.ai/en/latest/understanding/storing/storing/index.html’ saved [634354/634354]
#
# --2025-01-09 14:36:58--  https://docs.llamaindex.ai/en/latest/understanding/querying/querying/
# Reusing existing connection to [docs.llamaindex.ai]:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 636644 (622K) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/understanding/querying/querying/index.html’
#
# docs.llamaindex.ai/ 100%[===================>] 621.72K   913KB/s    in 0.7s
#
# 2025-01-09 14:36:59 (913 KB/s) - ‘docs.llamaindex.ai/en/latest/understanding/querying/querying/index.html’ saved [636644/636644]
#
# --2025-01-09 14:36:59--  https://docs.llamaindex.ai/en/latest/understanding/agent/
# Reusing existing connection to [docs.llamaindex.ai]:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 625880 (611K) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/understanding/agent/index.html’
#
# docs.llamaindex.ai/ 100%[===================>] 611.21K  --.-KB/s    in 0.08s
#
# 2025-01-09 14:37:00 (7.25 MB/s) - ‘docs.llamaindex.ai/en/latest/understanding/agent/index.html’ saved [625880/625880]
#
# --2025-01-09 14:37:00--  https://docs.llamaindex.ai/en/latest/understanding/agent/local_models/
# Reusing existing connection to [docs.llamaindex.ai]:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 626316 (612K) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/understanding/agent/local_models/index.html’
#
# docs.llamaindex.ai/ 100%[===================>] 611.64K  --.-KB/s    in 0.05s
#
# 2025-01-09 14:37:00 (11.5 MB/s) - ‘docs.llamaindex.ai/en/latest/understanding/agent/local_models/index.html’ saved [626316/626316]
#
# --2025-01-09 14:37:00--  https://docs.llamaindex.ai/en/latest/understanding/agent/rag_agent/
# Reusing existing connection to [docs.llamaindex.ai]:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 630329 (616K) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/understanding/agent/rag_agent/index.html’
#
# docs.llamaindex.ai/ 100%[===================>] 615.56K  --.-KB/s    in 0.07s
#
# 2025-01-09 14:37:01 (9.07 MB/s) - ‘docs.llamaindex.ai/en/latest/understanding/agent/rag_agent/index.html’ saved [630329/630329]
#
# --2025-01-09 14:37:01--  https://docs.llamaindex.ai/en/latest/understanding/agent/llamaparse/
# Reusing existing connection to [docs.llamaindex.ai]:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 624550 (610K) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/understanding/agent/llamaparse/index.html’
#
# docs.llamaindex.ai/ 100%[===================>] 609.91K  --.-KB/s    in 0.08s
#
# 2025-01-09 14:37:01 (7.28 MB/s) - ‘docs.llamaindex.ai/en/latest/understanding/agent/llamaparse/index.html’ saved [624550/624550]
#
# --2025-01-09 14:37:01--  https://docs.llamaindex.ai/en/latest/understanding/agent/memory/
# Reusing existing connection to [docs.llamaindex.ai]:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 624416 (610K) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/understanding/agent/memory/index.html’
#
# docs.llamaindex.ai/ 100%[===================>] 609.78K  --.-KB/s    in 0.08s
#
# 2025-01-09 14:37:02 (7.25 MB/s) - ‘docs.llamaindex.ai/en/latest/understanding/agent/memory/index.html’ saved [624416/624416]
#
# --2025-01-09 14:37:02--  https://docs.llamaindex.ai/en/latest/understanding/agent/tools/
# Reusing existing connection to [docs.llamaindex.ai]:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 629744 (615K) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/understanding/agent/tools/index.html’
#
# docs.llamaindex.ai/ 100%[===================>] 614.98K  --.-KB/s    in 0.05s
#
# 2025-01-09 14:37:02 (11.2 MB/s) - ‘docs.llamaindex.ai/en/latest/understanding/agent/tools/index.html’ saved [629744/629744]
#
# --2025-01-09 14:37:02--  https://docs.llamaindex.ai/en/latest/understanding/workflows/
# Reusing existing connection to [docs.llamaindex.ai]:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 620067 (606K) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/understanding/workflows/index.html’
#
# docs.llamaindex.ai/ 100%[===================>] 605.53K  --.-KB/s    in 0.05s
#
# 2025-01-09 14:37:03 (11.0 MB/s) - ‘docs.llamaindex.ai/en/latest/understanding/workflows/index.html’ saved [620067/620067]
#
# --2025-01-09 14:37:03--  https://docs.llamaindex.ai/en/latest/understanding/workflows/basic_flow/
# Reusing existing connection to [docs.llamaindex.ai]:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 638285 (623K) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/understanding/workflows/basic_flow/index.html’
#
# docs.llamaindex.ai/ 100%[===================>] 623.33K  --.-KB/s    in 0.06s
#
# 2025-01-09 14:37:04 (10.7 MB/s) - ‘docs.llamaindex.ai/en/latest/understanding/workflows/basic_flow/index.html’ saved [638285/638285]
#
# --2025-01-09 14:37:04--  https://docs.llamaindex.ai/en/latest/understanding/workflows/branches_and_loops/
# Reusing existing connection to [docs.llamaindex.ai]:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 630972 (616K) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/understanding/workflows/branches_and_loops/index.html’
#
# docs.llamaindex.ai/ 100%[===================>] 616.18K  --.-KB/s    in 0.05s
#
# 2025-01-09 14:37:04 (11.0 MB/s) - ‘docs.llamaindex.ai/en/latest/understanding/workflows/branches_and_loops/index.html’ saved [630972/630972]
#
# --2025-01-09 14:37:04--  https://docs.llamaindex.ai/en/latest/understanding/workflows/state/
# Reusing existing connection to [docs.llamaindex.ai]:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 627188 (612K) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/understanding/workflows/state/index.html’
#
# docs.llamaindex.ai/ 100%[===================>] 612.49K  --.-KB/s    in 0.08s
#
# 2025-01-09 14:37:05 (7.37 MB/s) - ‘docs.llamaindex.ai/en/latest/understanding/workflows/state/index.html’ saved [627188/627188]
#
# --2025-01-09 14:37:05--  https://docs.llamaindex.ai/en/latest/understanding/workflows/stream/
# Reusing existing connection to [docs.llamaindex.ai]:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 630102 (615K) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/understanding/workflows/stream/index.html’
#
# docs.llamaindex.ai/ 100%[===================>] 615.33K  --.-KB/s    in 0.07s
#
# 2025-01-09 14:37:05 (9.08 MB/s) - ‘docs.llamaindex.ai/en/latest/understanding/workflows/stream/index.html’ saved [630102/630102]
#
# --2025-01-09 14:37:05--  https://docs.llamaindex.ai/en/latest/understanding/workflows/concurrent_execution/
# Reusing existing connection to [docs.llamaindex.ai]:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 639092 (624K) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/understanding/workflows/concurrent_execution/index.html’
#
# docs.llamaindex.ai/ 100%[===================>] 624.11K  --.-KB/s    in 0.1s
#
# 2025-01-09 14:37:06 (5.56 MB/s) - ‘docs.llamaindex.ai/en/latest/understanding/workflows/concurrent_execution/index.html’ saved [639092/639092]
#
# --2025-01-09 14:37:06--  https://docs.llamaindex.ai/en/latest/understanding/workflows/subclass/
# Reusing existing connection to [docs.llamaindex.ai]:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 627666 (613K) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/understanding/workflows/subclass/index.html’
#
# docs.llamaindex.ai/ 100%[===================>] 612.96K  --.-KB/s    in 0.05s
#
# 2025-01-09 14:37:06 (10.9 MB/s) - ‘docs.llamaindex.ai/en/latest/understanding/workflows/subclass/index.html’ saved [627666/627666]
#
# --2025-01-09 14:37:06--  https://docs.llamaindex.ai/en/latest/understanding/workflows/nested/
# Reusing existing connection to [docs.llamaindex.ai]:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 631100 (616K) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/understanding/workflows/nested/index.html’
#
# docs.llamaindex.ai/ 100%[===================>] 616.31K  --.-KB/s    in 0.07s
#
# 2025-01-09 14:37:07 (8.21 MB/s) - ‘docs.llamaindex.ai/en/latest/understanding/workflows/nested/index.html’ saved [631100/631100]
#
# --2025-01-09 14:37:07--  https://docs.llamaindex.ai/en/latest/understanding/workflows/observability/
# Reusing existing connection to [docs.llamaindex.ai]:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 638533 (624K) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/understanding/workflows/observability/index.html’
#
# docs.llamaindex.ai/ 100%[===================>] 623.57K  --.-KB/s    in 0.08s
#
# 2025-01-09 14:37:08 (7.69 MB/s) - ‘docs.llamaindex.ai/en/latest/understanding/workflows/observability/index.html’ saved [638533/638533]
#
# --2025-01-09 14:37:08--  https://docs.llamaindex.ai/en/latest/understanding/workflows/unbound_functions/
# Reusing existing connection to [docs.llamaindex.ai]:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 622951 (608K) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/understanding/workflows/unbound_functions/index.html’
#
# docs.llamaindex.ai/ 100%[===================>] 608.35K  --.-KB/s    in 0.08s
#
# 2025-01-09 14:37:08 (7.83 MB/s) - ‘docs.llamaindex.ai/en/latest/understanding/workflows/unbound_functions/index.html’ saved [622951/622951]
#
# --2025-01-09 14:37:08--  https://docs.llamaindex.ai/en/latest/understanding/extraction/
# Reusing existing connection to [docs.llamaindex.ai]:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 633297 (618K) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/understanding/extraction/index.html’
#
# docs.llamaindex.ai/ 100%[===================>] 618.45K  --.-KB/s    in 0.07s
#
# 2025-01-09 14:37:09 (9.17 MB/s) - ‘docs.llamaindex.ai/en/latest/understanding/extraction/index.html’ saved [633297/633297]
#
# --2025-01-09 14:37:09--  https://docs.llamaindex.ai/en/latest/understanding/extraction/structured_llms/
# Reusing existing connection to [docs.llamaindex.ai]:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 631750 (617K) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/understanding/extraction/structured_llms/index.html’
#
# docs.llamaindex.ai/ 100%[===================>] 616.94K  --.-KB/s    in 0.08s
#
# 2025-01-09 14:37:09 (7.18 MB/s) - ‘docs.llamaindex.ai/en/latest/understanding/extraction/structured_llms/index.html’ saved [631750/631750]
#
# --2025-01-09 14:37:09--  https://docs.llamaindex.ai/en/latest/understanding/extraction/structured_prediction/
# Reusing existing connection to [docs.llamaindex.ai]:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 632303 (617K) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/understanding/extraction/structured_prediction/index.html’
#
# docs.llamaindex.ai/ 100%[===================>] 617.48K  --.-KB/s    in 0.05s
#
# 2025-01-09 14:37:10 (11.0 MB/s) - ‘docs.llamaindex.ai/en/latest/understanding/extraction/structured_prediction/index.html’ saved [632303/632303]
#
# --2025-01-09 14:37:10--  https://docs.llamaindex.ai/en/latest/understanding/extraction/lower_level/
# Reusing existing connection to [docs.llamaindex.ai]:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 630380 (616K) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/understanding/extraction/lower_level/index.html’
#
# docs.llamaindex.ai/ 100%[===================>] 615.61K  --.-KB/s    in 0.07s
#
# 2025-01-09 14:37:10 (8.35 MB/s) - ‘docs.llamaindex.ai/en/latest/understanding/extraction/lower_level/index.html’ saved [630380/630380]
#
# --2025-01-09 14:37:10--  https://docs.llamaindex.ai/en/latest/understanding/tracing_and_debugging/tracing_and_debugging/
# Reusing existing connection to [docs.llamaindex.ai]:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 625262 (611K) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/understanding/tracing_and_debugging/tracing_and_debugging/index.html’
#
# docs.llamaindex.ai/ 100%[===================>] 610.61K  --.-KB/s    in 0.05s
#
# 2025-01-09 14:37:11 (12.1 MB/s) - ‘docs.llamaindex.ai/en/latest/understanding/tracing_and_debugging/tracing_and_debugging/index.html’ saved [625262/625262]
#
# --2025-01-09 14:37:11--  https://docs.llamaindex.ai/en/latest/understanding/evaluating/evaluating/
# Reusing existing connection to [docs.llamaindex.ai]:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 627603 (613K) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/understanding/evaluating/evaluating/index.html’
#
# docs.llamaindex.ai/ 100%[===================>] 612.89K  --.-KB/s    in 0.07s
#
# 2025-01-09 14:37:11 (8.18 MB/s) - ‘docs.llamaindex.ai/en/latest/understanding/evaluating/evaluating/index.html’ saved [627603/627603]
#
# --2025-01-09 14:37:11--  https://docs.llamaindex.ai/en/latest/understanding/evaluating/cost_analysis/
# Reusing existing connection to [docs.llamaindex.ai]:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 628072 (613K) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/understanding/evaluating/cost_analysis/index.html’
#
# docs.llamaindex.ai/ 100%[===================>] 613.35K  --.-KB/s    in 0.1s
#
# 2025-01-09 14:37:12 (5.86 MB/s) - ‘docs.llamaindex.ai/en/latest/understanding/evaluating/cost_analysis/index.html’ saved [628072/628072]
#
# --2025-01-09 14:37:12--  https://docs.llamaindex.ai/en/latest/understanding/evaluating/cost_analysis/usage_pattern/
# Reusing existing connection to [docs.llamaindex.ai]:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 633313 (618K) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/understanding/evaluating/cost_analysis/usage_pattern/index.html’
#
# docs.llamaindex.ai/ 100%[===================>] 618.47K  --.-KB/s    in 0.07s
#
# 2025-01-09 14:37:12 (8.72 MB/s) - ‘docs.llamaindex.ai/en/latest/understanding/evaluating/cost_analysis/usage_pattern/index.html’ saved [633313/633313]
#
# --2025-01-09 14:37:12--  https://docs.llamaindex.ai/en/latest/understanding/putting_it_all_together/
# Reusing existing connection to [docs.llamaindex.ai]:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 616821 (602K) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/understanding/putting_it_all_together/index.html’
#
# docs.llamaindex.ai/ 100%[===================>] 602.36K  --.-KB/s    in 0.1s
#
# 2025-01-09 14:37:13 (3.95 MB/s) - ‘docs.llamaindex.ai/en/latest/understanding/putting_it_all_together/index.html’ saved [616821/616821]
#
# --2025-01-09 14:37:13--  https://docs.llamaindex.ai/en/latest/understanding/putting_it_all_together/apps/
# Reusing existing connection to [docs.llamaindex.ai]:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 620526 (606K) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/understanding/putting_it_all_together/apps/index.html’
#
# docs.llamaindex.ai/ 100%[===================>] 605.98K  --.-KB/s    in 0.1s
#
# 2025-01-09 14:37:14 (5.13 MB/s) - ‘docs.llamaindex.ai/en/latest/understanding/putting_it_all_together/apps/index.html’ saved [620526/620526]
#
# --2025-01-09 14:37:14--  https://docs.llamaindex.ai/en/latest/understanding/putting_it_all_together/apps/fullstack_app_guide/
# Reusing existing connection to [docs.llamaindex.ai]:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 673801 (658K) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/understanding/putting_it_all_together/apps/fullstack_app_guide/index.html’
#
# docs.llamaindex.ai/ 100%[===================>] 658.01K  3.47MB/s    in 0.2s
#
# 2025-01-09 14:37:14 (3.47 MB/s) - ‘docs.llamaindex.ai/en/latest/understanding/putting_it_all_together/apps/fullstack_app_guide/index.html’ saved [673801/673801]
#
# --2025-01-09 14:37:14--  https://docs.llamaindex.ai/en/latest/understanding/putting_it_all_together/apps/fullstack_with_delphic/
# Reusing existing connection to [docs.llamaindex.ai]:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 696142 (680K) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/understanding/putting_it_all_together/apps/fullstack_with_delphic/index.html’
#
# docs.llamaindex.ai/ 100%[===================>] 679.83K  1.74MB/s    in 0.4s
#
# 2025-01-09 14:37:15 (1.74 MB/s) - ‘docs.llamaindex.ai/en/latest/understanding/putting_it_all_together/apps/fullstack_with_delphic/index.html’ saved [696142/696142]
#
# --2025-01-09 14:37:15--  https://docs.llamaindex.ai/en/latest/understanding/putting_it_all_together/q_and_a/
# Reusing existing connection to [docs.llamaindex.ai]:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 638212 (623K) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/understanding/putting_it_all_together/q_and_a/index.html’
#
# docs.llamaindex.ai/ 100%[===================>] 623.25K  --.-KB/s    in 0.04s
#
# 2025-01-09 14:37:16 (14.0 MB/s) - ‘docs.llamaindex.ai/en/latest/understanding/putting_it_all_together/q_and_a/index.html’ saved [638212/638212]
#
# --2025-01-09 14:37:16--  https://docs.llamaindex.ai/en/latest/understanding/putting_it_all_together/q_and_a/terms_definitions_tutorial/
# Reusing existing connection to [docs.llamaindex.ai]:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 696728 (680K) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/understanding/putting_it_all_together/q_and_a/terms_definitions_tutorial/index.html’
#
# docs.llamaindex.ai/ 100%[===================>] 680.40K  --.-KB/s    in 0.09s
#
# 2025-01-09 14:37:16 (7.73 MB/s) - ‘docs.llamaindex.ai/en/latest/understanding/putting_it_all_together/q_and_a/terms_definitions_tutorial/index.html’ saved [696728/696728]
#
# --2025-01-09 14:37:16--  https://docs.llamaindex.ai/en/latest/understanding/putting_it_all_together/chatbots/building_a_chatbot/
# Reusing existing connection to [docs.llamaindex.ai]:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 663768 (648K) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/understanding/putting_it_all_together/chatbots/building_a_chatbot/index.html’
#
# docs.llamaindex.ai/ 100%[===================>] 648.21K  --.-KB/s    in 0.06s
#
# 2025-01-09 14:37:17 (11.2 MB/s) - ‘docs.llamaindex.ai/en/latest/understanding/putting_it_all_together/chatbots/building_a_chatbot/index.html’ saved [663768/663768]
#
# --2025-01-09 14:37:17--  https://docs.llamaindex.ai/en/latest/understanding/putting_it_all_together/structured_data/
# Reusing existing connection to [docs.llamaindex.ai]:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 634608 (620K) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/understanding/putting_it_all_together/structured_data/index.html’
#
# docs.llamaindex.ai/ 100%[===================>] 619.73K  --.-KB/s    in 0.07s
#
# 2025-01-09 14:37:17 (9.01 MB/s) - ‘docs.llamaindex.ai/en/latest/understanding/putting_it_all_together/structured_data/index.html’ saved [634608/634608]
#
# --2025-01-09 14:37:17--  https://docs.llamaindex.ai/en/latest/understanding/putting_it_all_together/agents/
# Reusing existing connection to [docs.llamaindex.ai]:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 631083 (616K) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/understanding/putting_it_all_together/agents/index.html’
#
# docs.llamaindex.ai/ 100%[===================>] 616.29K  --.-KB/s    in 0.06s
#
# 2025-01-09 14:37:18 (10.9 MB/s) - ‘docs.llamaindex.ai/en/latest/understanding/putting_it_all_together/agents/index.html’ saved [631083/631083]
#
# --2025-01-09 14:37:18--  https://docs.llamaindex.ai/en/latest/use_cases/prompting/
# Reusing existing connection to [docs.llamaindex.ai]:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 620771 (606K) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/use_cases/prompting/index.html’
#
# docs.llamaindex.ai/ 100%[===================>] 606.22K  --.-KB/s    in 0.05s
#
# 2025-01-09 14:37:18 (11.9 MB/s) - ‘docs.llamaindex.ai/en/latest/use_cases/prompting/index.html’ saved [620771/620771]
#
# --2025-01-09 14:37:18--  https://docs.llamaindex.ai/en/latest/use_cases/q_and_a/
# Reusing existing connection to [docs.llamaindex.ai]:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 623980 (609K) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/use_cases/q_and_a/index.html’
#
# docs.llamaindex.ai/ 100%[===================>] 609.36K  --.-KB/s    in 0.05s
#
# 2025-01-09 14:37:19 (11.2 MB/s) - ‘docs.llamaindex.ai/en/latest/use_cases/q_and_a/index.html’ saved [623980/623980]
#
# --2025-01-09 14:37:19--  https://docs.llamaindex.ai/en/latest/use_cases/chatbots/
# Reusing existing connection to [docs.llamaindex.ai]:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 618947 (604K) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/use_cases/chatbots/index.html’
#
# docs.llamaindex.ai/ 100%[===================>] 604.44K  --.-KB/s    in 0.06s
#
# 2025-01-09 14:37:19 (10.6 MB/s) - ‘docs.llamaindex.ai/en/latest/use_cases/chatbots/index.html’ saved [618947/618947]
#
# --2025-01-09 14:37:19--  https://docs.llamaindex.ai/en/latest/use_cases/extraction/
# Reusing existing connection to [docs.llamaindex.ai]:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 619799 (605K) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/use_cases/extraction/index.html’
#
# docs.llamaindex.ai/ 100%[===================>] 605.27K   569KB/s    in 1.1s
#
# 2025-01-09 14:37:21 (569 KB/s) - ‘docs.llamaindex.ai/en/latest/use_cases/extraction/index.html’ saved [619799/619799]
#
# --2025-01-09 14:37:21--  https://docs.llamaindex.ai/en/latest/use_cases/agents/
# Reusing existing connection to [docs.llamaindex.ai]:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 622820 (608K) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/use_cases/agents/index.html’
#
# docs.llamaindex.ai/ 100%[===================>] 608.22K   521KB/s    in 1.2s
#
# 2025-01-09 14:37:22 (521 KB/s) - ‘docs.llamaindex.ai/en/latest/use_cases/agents/index.html’ saved [622820/622820]
#
# --2025-01-09 14:37:22--  https://docs.llamaindex.ai/en/latest/use_cases/multimodal/
# Reusing existing connection to [docs.llamaindex.ai]:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 626343 (612K) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/use_cases/multimodal/index.html’
#
# docs.llamaindex.ai/ 100%[===================>] 611.66K   920KB/s    in 0.7s
#
# 2025-01-09 14:37:23 (920 KB/s) - ‘docs.llamaindex.ai/en/latest/use_cases/multimodal/index.html’ saved [626343/626343]
#
# --2025-01-09 14:37:23--  https://docs.llamaindex.ai/en/latest/use_cases/fine_tuning/
# Reusing existing connection to [docs.llamaindex.ai]:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 631146 (616K) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/use_cases/fine_tuning/index.html’
#
# docs.llamaindex.ai/ 100%[===================>] 616.35K   963KB/s    in 0.6s
#
# 2025-01-09 14:37:25 (963 KB/s) - ‘docs.llamaindex.ai/en/latest/use_cases/fine_tuning/index.html’ saved [631146/631146]
#
# --2025-01-09 14:37:25--  https://docs.llamaindex.ai/en/latest/examples/agent/Chatbot_SEC/
# Reusing existing connection to [docs.llamaindex.ai]:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1301987 (1.2M) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/agent/Chatbot_SEC/index.html’
#
# docs.llamaindex.ai/ 100%[===================>]   1.24M  1.59MB/s    in 0.8s
#
# 2025-01-09 14:37:26 (1.59 MB/s) - ‘docs.llamaindex.ai/en/latest/examples/agent/Chatbot_SEC/index.html’ saved [1301987/1301987]
#
# --2025-01-09 14:37:26--  https://docs.llamaindex.ai/en/latest/examples/agent/agent_builder/
# Reusing existing connection to [docs.llamaindex.ai]:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1278936 (1.2M) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/agent/agent_builder/index.html’
#
# docs.llamaindex.ai/ 100%[===================>]   1.22M   525KB/s    in 2.4s
#
# 2025-01-09 14:37:29 (525 KB/s) - ‘docs.llamaindex.ai/en/latest/examples/agent/agent_builder/index.html’ saved [1278936/1278936]
#
# --2025-01-09 14:37:29--  https://docs.llamaindex.ai/en/latest/examples/agent/agent_runner/agent_around_query_pipeline_with_HyDE_for_PDFs/
# Reusing existing connection to [docs.llamaindex.ai]:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1392858 (1.3M) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/agent/agent_runner/agent_around_query_pipeline_with_HyDE_for_PDFs/index.html’
#
# docs.llamaindex.ai/ 100%[===================>]   1.33M   701KB/s    in 1.9s
#
# 2025-01-09 14:37:31 (701 KB/s) - ‘docs.llamaindex.ai/en/latest/examples/agent/agent_runner/agent_around_query_pipeline_with_HyDE_for_PDFs/index.html’ saved [1392858/1392858]
#
# --2025-01-09 14:37:31--  https://docs.llamaindex.ai/en/latest/examples/agent/agent_runner/agent_runner/
# Reusing existing connection to [docs.llamaindex.ai]:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1317500 (1.3M) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/agent/agent_runner/agent_runner/index.html’
#
# docs.llamaindex.ai/ 100%[===================>]   1.26M   807KB/s    in 1.6s
#
# 2025-01-09 14:37:34 (807 KB/s) - ‘docs.llamaindex.ai/en/latest/examples/agent/agent_runner/agent_runner/index.html’ saved [1317500/1317500]
#
# --2025-01-09 14:37:34--  https://docs.llamaindex.ai/en/latest/examples/agent/agent_runner/agent_runner_rag_controllable/
# Reusing existing connection to [docs.llamaindex.ai]:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1330657 (1.3M) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/agent/agent_runner/agent_runner_rag_controllable/index.html’
#
# docs.llamaindex.ai/ 100%[===================>]   1.27M   816KB/s    in 1.6s
#
# 2025-01-09 14:37:36 (816 KB/s) - ‘docs.llamaindex.ai/en/latest/examples/agent/agent_runner/agent_runner_rag_controllable/index.html’ saved [1330657/1330657]
#
# --2025-01-09 14:37:36--  https://docs.llamaindex.ai/en/latest/examples/agent/agent_runner/query_pipeline_agent/
# Reusing existing connection to [docs.llamaindex.ai]:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1365523 (1.3M) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/agent/agent_runner/query_pipeline_agent/index.html’
#
# docs.llamaindex.ai/ 100%[===================>]   1.30M   572KB/s    in 2.3s
#
# 2025-01-09 14:37:39 (572 KB/s) - ‘docs.llamaindex.ai/en/latest/examples/agent/agent_runner/query_pipeline_agent/index.html’ saved [1365523/1365523]
#
# --2025-01-09 14:37:39--  https://docs.llamaindex.ai/en/latest/examples/agent/agentic_rag_using_vertex_ai/
# Reusing existing connection to [docs.llamaindex.ai]:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1390078 (1.3M) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/agent/agentic_rag_using_vertex_ai/index.html’
#
# docs.llamaindex.ai/ 100%[===================>]   1.33M   738KB/s    in 1.8s
#
# 2025-01-09 14:37:41 (738 KB/s) - ‘docs.llamaindex.ai/en/latest/examples/agent/agentic_rag_using_vertex_ai/index.html’ saved [1390078/1390078]
#
# --2025-01-09 14:37:41--  https://docs.llamaindex.ai/en/latest/examples/agent/agentic_rag_with_llamaindex_and_vertexai_managed_index/
# Reusing existing connection to [docs.llamaindex.ai]:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1370319 (1.3M) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/agent/agentic_rag_with_llamaindex_and_vertexai_managed_index/index.html’
#
# docs.llamaindex.ai/ 100%[===================>]   1.31M  1.02MB/s    in 1.3s
#
# 2025-01-09 14:37:43 (1.02 MB/s) - ‘docs.llamaindex.ai/en/latest/examples/agent/agentic_rag_with_llamaindex_and_vertexai_managed_index/index.html’ saved [1370319/1370319]
#
# --2025-01-09 14:37:43--  https://docs.llamaindex.ai/en/latest/examples/agent/anthropic_agent/
# Reusing existing connection to [docs.llamaindex.ai]:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1268510 (1.2M) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/agent/anthropic_agent/index.html’
#
# docs.llamaindex.ai/ 100%[===================>]   1.21M  1.05MB/s    in 1.1s
#
# 2025-01-09 14:37:44 (1.05 MB/s) - ‘docs.llamaindex.ai/en/latest/examples/agent/anthropic_agent/index.html’ saved [1268510/1268510]
#
# --2025-01-09 14:37:44--  https://docs.llamaindex.ai/en/latest/examples/agent/bedrock_converse_agent/
# Reusing existing connection to [docs.llamaindex.ai]:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1264186 (1.2M) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/agent/bedrock_converse_agent/index.html’
#
# docs.llamaindex.ai/ 100%[===================>]   1.21M  1.06MB/s    in 1.1s
#
# 2025-01-09 14:37:46 (1.06 MB/s) - ‘docs.llamaindex.ai/en/latest/examples/agent/bedrock_converse_agent/index.html’ saved [1264186/1264186]
#
# --2025-01-09 14:37:46--  https://docs.llamaindex.ai/en/latest/examples/agent/coa_agent/
# Reusing existing connection to [docs.llamaindex.ai]:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1273669 (1.2M) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/agent/coa_agent/index.html’
#
# docs.llamaindex.ai/ 100%[===================>]   1.21M  1.12MB/s    in 1.1s
#
# 2025-01-09 14:37:48 (1.12 MB/s) - ‘docs.llamaindex.ai/en/latest/examples/agent/coa_agent/index.html’ saved [1273669/1273669]
#
# --2025-01-09 14:37:48--  https://docs.llamaindex.ai/en/latest/examples/agent/custom_agent/
# Reusing existing connection to [docs.llamaindex.ai]:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1337330 (1.3M) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/agent/custom_agent/index.html’
#
# docs.llamaindex.ai/ 100%[===================>]   1.27M   562KB/s    in 2.3s
#
# 2025-01-09 14:37:51 (562 KB/s) - ‘docs.llamaindex.ai/en/latest/examples/agent/custom_agent/index.html’ saved [1337330/1337330]
#
# --2025-01-09 14:37:51--  https://docs.llamaindex.ai/en/latest/examples/agent/dashscope_agent/
# Reusing existing connection to [docs.llamaindex.ai]:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1250684 (1.2M) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/agent/dashscope_agent/index.html’
#
# docs.llamaindex.ai/ 100%[===================>]   1.19M   239KB/s    in 5.1s
#
# 2025-01-09 14:37:57 (239 KB/s) - ‘docs.llamaindex.ai/en/latest/examples/agent/dashscope_agent/index.html’ saved [1250684/1250684]
#
# --2025-01-09 14:37:57--  https://docs.llamaindex.ai/en/latest/examples/agent/introspective_agent_toxicity_reduction/
# Reusing existing connection to [docs.llamaindex.ai]:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1332839 (1.3M) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/agent/introspective_agent_toxicity_reduction/index.html’
#
# docs.llamaindex.ai/ 100%[===================>]   1.27M  1.45MB/s    in 0.9s
#
# 2025-01-09 14:37:59 (1.45 MB/s) - ‘docs.llamaindex.ai/en/latest/examples/agent/introspective_agent_toxicity_reduction/index.html’ saved [1332839/1332839]
#
# --2025-01-09 14:37:59--  https://docs.llamaindex.ai/en/latest/examples/agent/lats_agent/
# Reusing existing connection to [docs.llamaindex.ai]:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1324233 (1.3M) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/agent/lats_agent/index.html’
#
# docs.llamaindex.ai/ 100%[===================>]   1.26M  2.09MB/s    in 0.6s
#
# 2025-01-09 14:38:00 (2.09 MB/s) - ‘docs.llamaindex.ai/en/latest/examples/agent/lats_agent/index.html’ saved [1324233/1324233]
#
# --2025-01-09 14:38:00--  https://docs.llamaindex.ai/en/latest/examples/agent/llm_compiler/
# Reusing existing connection to [docs.llamaindex.ai]:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1297047 (1.2M) [text/html]
# ...
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 659294 (644K) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/storage/vector_store/timescalevector/index.html’
#
# docs.llamaindex.ai/ 100%[===================>] 643.84K  --.-KB/s    in 0.03s
#
# 2025-01-09 14:55:15 (20.9 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/storage/vector_store/timescalevector/index.html’ saved [659294/659294]
#
# --2025-01-09 14:55:15--  https://docs.llamaindex.ai/en/latest/api_reference/storage/vector_store/txtai/
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 676438 (661K) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/storage/vector_store/txtai/index.html’
#
# docs.llamaindex.ai/ 100%[===================>] 660.58K  --.-KB/s    in 0.007s
#
# 2025-01-09 14:55:16 (93.2 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/storage/vector_store/txtai/index.html’ saved [676438/676438]
#
# --2025-01-09 14:55:16--  https://docs.llamaindex.ai/en/latest/api_reference/storage/vector_store/typesense/
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 691437 (675K) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/storage/vector_store/typesense/index.html’
#
# docs.llamaindex.ai/ 100%[===================>] 675.23K  --.-KB/s    in 0.03s
#
# 2025-01-09 14:55:16 (19.1 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/storage/vector_store/typesense/index.html’ saved [691437/691437]
#
# --2025-01-09 14:55:16--  https://docs.llamaindex.ai/en/latest/api_reference/storage/vector_store/upstash/
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 654880 (640K) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/storage/vector_store/upstash/index.html’
#
# docs.llamaindex.ai/ 100%[===================>] 639.53K  --.-KB/s    in 0.03s
#
# 2025-01-09 14:55:17 (20.6 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/storage/vector_store/upstash/index.html’ saved [654880/654880]
#
# --2025-01-09 14:55:17--  https://docs.llamaindex.ai/en/latest/api_reference/storage/vector_store/vearch/
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 691943 (676K) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/storage/vector_store/vearch/index.html’
#
# docs.llamaindex.ai/ 100%[===================>] 675.73K  --.-KB/s    in 0.03s
#
# 2025-01-09 14:55:17 (20.5 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/storage/vector_store/vearch/index.html’ saved [691943/691943]
#
# --2025-01-09 14:55:17--  https://docs.llamaindex.ai/en/latest/api_reference/storage/vector_store/vertexaivectorsearch/
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 693042 (677K) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/storage/vector_store/vertexaivectorsearch/index.html’
#
# docs.llamaindex.ai/ 100%[===================>] 676.80K  --.-KB/s    in 0.01s
#
# 2025-01-09 14:55:18 (47.2 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/storage/vector_store/vertexaivectorsearch/index.html’ saved [693042/693042]
#
# --2025-01-09 14:55:18--  https://docs.llamaindex.ai/en/latest/api_reference/storage/vector_store/vespa/
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 766258 (748K) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/storage/vector_store/vespa/index.html’
#
# docs.llamaindex.ai/ 100%[===================>] 748.30K  --.-KB/s    in 0.04s
#
# 2025-01-09 14:55:19 (20.6 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/storage/vector_store/vespa/index.html’ saved [766258/766258]
#
# --2025-01-09 14:55:19--  https://docs.llamaindex.ai/en/latest/api_reference/storage/vector_store/weaviate/
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 764352 (746K) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/storage/vector_store/weaviate/index.html’
#
# docs.llamaindex.ai/ 100%[===================>] 746.44K  --.-KB/s    in 0.06s
#
# 2025-01-09 14:55:19 (11.3 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/storage/vector_store/weaviate/index.html’ saved [764352/764352]
#
# --2025-01-09 14:55:19--  https://docs.llamaindex.ai/en/latest/api_reference/storage/vector_store/wordlift/
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 649618 (634K) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/storage/vector_store/wordlift/index.html’
#
# docs.llamaindex.ai/ 100%[===================>] 634.39K  --.-KB/s    in 0.007s
#
# 2025-01-09 14:55:20 (93.9 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/storage/vector_store/wordlift/index.html’ saved [649618/649618]
#
# --2025-01-09 14:55:20--  https://docs.llamaindex.ai/en/latest/api_reference/storage/vector_store/zep/
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 713788 (697K) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/storage/vector_store/zep/index.html’
#
# docs.llamaindex.ai/ 100%[===================>] 697.06K  --.-KB/s    in 0.03s
#
# 2025-01-09 14:55:20 (21.8 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/storage/vector_store/zep/index.html’ saved [713788/713788]
#
# --2025-01-09 14:55:20--  https://docs.llamaindex.ai/en/latest/api_reference/tools/
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 663428 (648K) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/tools/index.html’
#
# docs.llamaindex.ai/ 100%[===================>] 647.88K  --.-KB/s    in 0.03s
#
# 2025-01-09 14:55:21 (20.7 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/tools/index.html’ saved [663428/663428]
#
# --2025-01-09 14:55:21--  https://docs.llamaindex.ai/en/latest/api_reference/tools/arxiv/
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 621518 (607K) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/tools/arxiv/index.html’
#
# docs.llamaindex.ai/ 100%[===================>] 606.95K  --.-KB/s    in 0.03s
#
# 2025-01-09 14:55:21 (19.7 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/tools/arxiv/index.html’ saved [621518/621518]
#
# --2025-01-09 14:55:21--  https://docs.llamaindex.ai/en/latest/api_reference/tools/azure_code_interpreter/
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 700011 (684K) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/tools/azure_code_interpreter/index.html’
#
# docs.llamaindex.ai/ 100%[===================>] 683.60K  --.-KB/s    in 0.009s
#
# 2025-01-09 14:55:22 (78.3 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/tools/azure_code_interpreter/index.html’ saved [700011/700011]
#
# --2025-01-09 14:55:22--  https://docs.llamaindex.ai/en/latest/api_reference/tools/azure_cv/
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 623020 (608K) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/tools/azure_cv/index.html’
#
# docs.llamaindex.ai/ 100%[===================>] 608.42K  --.-KB/s    in 0.03s
#
# 2025-01-09 14:55:22 (19.9 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/tools/azure_cv/index.html’ saved [623020/623020]
#
# --2025-01-09 14:55:22--  https://docs.llamaindex.ai/en/latest/api_reference/tools/azure_speech/
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 634255 (619K) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/tools/azure_speech/index.html’
#
# docs.llamaindex.ai/ 100%[===================>] 619.39K  --.-KB/s    in 0.03s
#
# 2025-01-09 14:55:23 (18.5 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/tools/azure_speech/index.html’ saved [634255/634255]
#
# --2025-01-09 14:55:23--  https://docs.llamaindex.ai/en/latest/api_reference/tools/azure_translate/
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 618825 (604K) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/tools/azure_translate/index.html’
#
# docs.llamaindex.ai/ 100%[===================>] 604.32K  --.-KB/s    in 0.008s
#
# 2025-01-09 14:55:23 (72.4 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/tools/azure_translate/index.html’ saved [618825/618825]
#
# --2025-01-09 14:55:24--  https://docs.llamaindex.ai/en/latest/api_reference/tools/bing_search/
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 629560 (615K) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/tools/bing_search/index.html’
#
# docs.llamaindex.ai/ 100%[===================>] 614.80K  --.-KB/s    in 0.03s
#
# 2025-01-09 14:55:24 (17.8 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/tools/bing_search/index.html’ saved [629560/629560]
#
# --2025-01-09 14:55:24--  https://docs.llamaindex.ai/en/latest/api_reference/tools/box/
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 727862 (711K) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/tools/box/index.html’
#
# docs.llamaindex.ai/ 100%[===================>] 710.80K  --.-KB/s    in 0.04s
#
# 2025-01-09 14:55:24 (18.4 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/tools/box/index.html’ saved [727862/727862]
#
# --2025-01-09 14:55:24--  https://docs.llamaindex.ai/en/latest/api_reference/tools/brave_search/
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 624570 (610K) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/tools/brave_search/index.html’
#
# docs.llamaindex.ai/ 100%[===================>] 609.93K  --.-KB/s    in 0.03s
#
# 2025-01-09 14:55:25 (18.5 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/tools/brave_search/index.html’ saved [624570/624570]
#
# --2025-01-09 14:55:25--  https://docs.llamaindex.ai/en/latest/api_reference/tools/cassandra/
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 639550 (625K) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/tools/cassandra/index.html’
#
# docs.llamaindex.ai/ 100%[===================>] 624.56K  --.-KB/s    in 0.03s
#
# 2025-01-09 14:55:25 (19.3 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/tools/cassandra/index.html’ saved [639550/639550]
#
# --2025-01-09 14:55:25--  https://docs.llamaindex.ai/en/latest/api_reference/tools/chatgpt_plugin/
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 623845 (609K) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/tools/chatgpt_plugin/index.html’
#
# docs.llamaindex.ai/ 100%[===================>] 609.22K  --.-KB/s    in 0.1s
#
# 2025-01-09 14:55:26 (5.24 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/tools/chatgpt_plugin/index.html’ saved [623845/623845]
#
# --2025-01-09 14:55:26--  https://docs.llamaindex.ai/en/latest/api_reference/tools/code_interpreter/
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 618362 (604K) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/tools/code_interpreter/index.html’
#
# docs.llamaindex.ai/ 100%[===================>] 603.87K  --.-KB/s    in 0.05s
#
# 2025-01-09 14:55:26 (11.5 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/tools/code_interpreter/index.html’ saved [618362/618362]
#
# --2025-01-09 14:55:27--  https://docs.llamaindex.ai/en/latest/api_reference/tools/cogniswitch/
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 659290 (644K) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/tools/cogniswitch/index.html’
#
# docs.llamaindex.ai/ 100%[===================>] 643.84K  --.-KB/s    in 0.04s
#
# 2025-01-09 14:55:27 (14.5 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/tools/cogniswitch/index.html’ saved [659290/659290]
#
# --2025-01-09 14:55:27--  https://docs.llamaindex.ai/en/latest/api_reference/tools/database/
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 652170 (637K) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/tools/database/index.html’
#
# docs.llamaindex.ai/ 100%[===================>] 636.88K  --.-KB/s    in 0.03s
#
# 2025-01-09 14:55:28 (18.8 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/tools/database/index.html’ saved [652170/652170]
#
# --2025-01-09 14:55:28--  https://docs.llamaindex.ai/en/latest/api_reference/tools/docker_code.md
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 404 Not Found
# 2025-01-09 14:55:28 ERROR 404: Not Found.
#
# --2025-01-09 14:55:28--  https://docs.llamaindex.ai/en/latest/api_reference/tools/duckduckgo/
# Connecting to docs.llamaindex.ai (docs.llamaindex.ai)|104.18.1.163|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 627935 (613K) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/tools/duckduckgo/index.html’
#
# docs.llamaindex.ai/ 100%[===================>] 613.22K  3.08MB/s    in 0.2s
#
# 2025-01-09 14:55:29 (3.08 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/tools/duckduckgo/index.html’ saved [627935/627935]
#
# --2025-01-09 14:55:29--  https://docs.llamaindex.ai/en/latest/api_reference/tools/elevenlabs/
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 647231 (632K) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/tools/elevenlabs/index.html’
#
# docs.llamaindex.ai/ 100%[===================>] 632.06K  --.-KB/s    in 0.06s
#
# 2025-01-09 14:55:30 (10.5 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/tools/elevenlabs/index.html’ saved [647231/647231]
#
# --2025-01-09 14:55:30--  https://docs.llamaindex.ai/en/latest/api_reference/tools/exa/
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 695772 (679K) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/tools/exa/index.html’
#
# docs.llamaindex.ai/ 100%[===================>] 679.46K  --.-KB/s    in 0.03s
#
# 2025-01-09 14:55:30 (20.0 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/tools/exa/index.html’ saved [695772/695772]
#
# --2025-01-09 14:55:30--  https://docs.llamaindex.ai/en/latest/api_reference/tools/finance/
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 687325 (671K) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/tools/finance/index.html’
#
# docs.llamaindex.ai/ 100%[===================>] 671.22K  --.-KB/s    in 0.03s
#
# 2025-01-09 14:55:31 (19.8 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/tools/finance/index.html’ saved [687325/687325]
#
# --2025-01-09 14:55:31--  https://docs.llamaindex.ai/en/latest/api_reference/tools/function/
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 653120 (638K) [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/tools/function/index.html’
#
# docs.llamaindex.ai/ 100%[===================>] 637.81K  --.-KB/s    in 0.03s
#
# 2025-01-09 14:55:31 (19.3 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/tools/function/index.html’ saved [653120/653120]
#
# --2025-01-09 14:55:31--  https://docs.llamaindex.ai/en/latest/api_reference/tools/google/
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... ^C

# %%
# %pip install -U unstructured
# Out:
# Collecting unstructured
#   Downloading unstructured-0.16.12-py3-none-any.whl (1.7 MB)
#      |████████████████████████████████| 1.7 MB 1.1 MB/s eta 0:00:01
# Requirement already satisfied: psutil in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from unstructured) (6.1.1)
# Requirement already satisfied: tqdm in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from unstructured) (4.67.1)
# Collecting python-oxmsg
#   Downloading python_oxmsg-0.0.1-py3-none-any.whl (31 kB)
# Collecting numpy<2
#   Using cached numpy-1.26.4-cp310-cp310-macosx_11_0_arm64.whl (14.0 MB)
# Collecting langdetect
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      |████████████████████████████████| 981 kB 17.4 MB/s eta 0:00:01
# Collecting rapidfuzz
#   Downloading rapidfuzz-3.11.0-cp310-cp310-macosx_11_0_arm64.whl (1.4 MB)
#      |████████████████████████████████| 1.4 MB 16.7 MB/s eta 0:00:01
# Collecting backoff
#   Using cached backoff-2.2.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: requests in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from unstructured) (2.32.3)
# Collecting python-iso639
#   Downloading python_iso639-2024.10.22-py3-none-any.whl (274 kB)
#      |████████████████████████████████| 274 kB 32.6 MB/s eta 0:00:01
# Collecting ndjson
#   Downloading ndjson-0.3.1-py2.py3-none-any.whl (5.3 kB)
# Collecting chardet
#   Using cached chardet-5.2.0-py3-none-any.whl (199 kB)
# Collecting lxml
#   Using cached lxml-5.3.0-cp310-cp310-macosx_10_9_universal2.whl (8.1 MB)
# Requirement already satisfied: wrapt in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from unstructured) (1.17.0)
# Requirement already satisfied: typing-extensions in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from unstructured) (4.12.2)
# Collecting unstructured-client
#   Downloading unstructured_client-0.28.1-py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 5.8 MB/s  eta 0:00:01
# Collecting html5lib
#   Downloading html5lib-1.1-py2.py3-none-any.whl (112 kB)
#      |████████████████████████████████| 112 kB 27.0 MB/s eta 0:00:01
# Requirement already satisfied: filetype in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from unstructured) (1.2.0)
# Requirement already satisfied: beautifulsoup4 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from unstructured) (4.12.3)
# Requirement already satisfied: nltk in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from unstructured) (3.9.1)
# Collecting python-magic
#   Downloading python_magic-0.4.27-py2.py3-none-any.whl (13 kB)
# Requirement already satisfied: dataclasses-json in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from unstructured) (0.6.7)
# Collecting emoji
#   Downloading emoji-2.14.0-py3-none-any.whl (586 kB)
#      |████████████████████████████████| 586 kB 14.4 MB/s eta 0:00:01
# Requirement already satisfied: soupsieve>1.2 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from beautifulsoup4->unstructured) (2.6)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from dataclasses-json->unstructured) (0.9.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from dataclasses-json->unstructured) (3.25.0)
# Requirement already satisfied: packaging>=17.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->unstructured) (24.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json->unstructured) (1.0.0)
# Collecting webencodings
#   Using cached webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: six>=1.9 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from html5lib->unstructured) (1.17.0)
# Requirement already satisfied: regex>=2021.8.3 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from nltk->unstructured) (2024.11.6)
# Requirement already satisfied: joblib in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from nltk->unstructured) (1.4.2)
# Requirement already satisfied: click in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from nltk->unstructured) (8.1.8)
# Collecting olefile
#   Downloading olefile-0.47-py2.py3-none-any.whl (114 kB)
#      |████████████████████████████████| 114 kB 18.9 MB/s eta 0:00:01
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from requests->unstructured) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from requests->unstructured) (2.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from requests->unstructured) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from requests->unstructured) (2024.12.14)
# Collecting eval-type-backport<0.3.0,>=0.2.0
#   Downloading eval_type_backport-0.2.2-py3-none-any.whl (5.8 kB)
# Requirement already satisfied: httpx>=0.27.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from unstructured-client->unstructured) (0.28.1)
# Requirement already satisfied: pypdf>=4.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from unstructured-client->unstructured) (5.1.0)
# Collecting cryptography>=3.1
#   Downloading cryptography-44.0.0-cp39-abi3-macosx_10_9_universal2.whl (6.5 MB)
#      |████████████████████████████████| 6.5 MB 27.7 MB/s eta 0:00:01
# Collecting jsonpath-python<2.0.0,>=1.0.6
#   Using cached jsonpath_python-1.0.6-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: nest-asyncio>=1.6.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from unstructured-client->unstructured) (1.6.0)
# Collecting pydantic<2.10.0,>=2.9.2
#   Using cached pydantic-2.9.2-py3-none-any.whl (434 kB)
# Collecting aiofiles>=24.1.0
#   Downloading aiofiles-24.1.0-py3-none-any.whl (15 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.2 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from unstructured-client->unstructured) (2.9.0.post0)
# Collecting requests-toolbelt>=1.0.0
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
#      |████████████████████████████████| 54 kB 12.2 MB/s eta 0:00:01
# Collecting cffi>=1.12
#   Downloading cffi-1.17.1-cp310-cp310-macosx_11_0_arm64.whl (178 kB)
#      |████████████████████████████████| 178 kB 21.5 MB/s eta 0:00:01
# Collecting pycparser
#   Using cached pycparser-2.22-py3-none-any.whl (117 kB)
# Requirement already satisfied: anyio in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from httpx>=0.27.0->unstructured-client->unstructured) (4.8.0)
# Requirement already satisfied: httpcore==1.* in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from httpx>=0.27.0->unstructured-client->unstructured) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from httpcore==1.*->httpx>=0.27.0->unstructured-client->unstructured) (0.14.0)
# Collecting pydantic-core==2.23.4
#   Using cached pydantic_core-2.23.4-cp310-cp310-macosx_11_0_arm64.whl (1.8 MB)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from pydantic<2.10.0,>=2.9.2->unstructured-client->unstructured) (0.7.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from anyio->httpx>=0.27.0->unstructured-client->unstructured) (1.2.2)
# Requirement already satisfied: sniffio>=1.1 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from anyio->httpx>=0.27.0->unstructured-client->unstructured) (1.3.1)
# Using legacy 'setup.py install' for langdetect, since package 'wheel' is not installed.
# Installing collected packages: pycparser, pydantic-core, cffi, webencodings, requests-toolbelt, pydantic, olefile, jsonpath-python, eval-type-backport, cryptography, aiofiles, unstructured-client, rapidfuzz, python-oxmsg, python-magic, python-iso639, numpy, ndjson, lxml, langdetect, html5lib, emoji, chardet, backoff, unstructured
#   Attempting uninstall: pydantic-core
#     Found existing installation: pydantic-core 2.27.2
#     Uninstalling pydantic-core-2.27.2:
#       Successfully uninstalled pydantic-core-2.27.2
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.10.5
#     Uninstalling pydantic-2.10.5:
#       Successfully uninstalled pydantic-2.10.5
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.2.1
#     Uninstalling numpy-2.2.1:
#       Successfully uninstalled numpy-2.2.1
#     Running setup.py install for langdetect ... done
# Successfully installed aiofiles-24.1.0 backoff-2.2.1 cffi-1.17.1 chardet-5.2.0 cryptography-44.0.0 emoji-2.14.0 eval-type-backport-0.2.2 html5lib-1.1 jsonpath-python-1.0.6 langdetect-1.0.9 lxml-5.3.0 ndjson-0.3.1 numpy-1.26.4 olefile-0.47 pycparser-2.22 pydantic-2.9.2 pydantic-core-2.23.4 python-iso639-2024.10.22 python-magic-0.4.27 python-oxmsg-0.0.1 rapidfuzz-3.11.0 requests-toolbelt-1.0.0 unstructured-0.16.12 unstructured-client-0.28.1 webencodings-0.5.1
# WARNING: You are using pip version 21.2.3; however, version 24.3.1 is available.
# You should consider upgrading via the '/Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
from llama_index.readers.file import UnstructuredReader

reader = UnstructuredReader()

# %%
pwd
# Out:
# '/Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/test'

# %% [raw]
# all_files_gen = Path("./app/files").rglob("*")

# %%
all_files_gen
# Out:
# <generator object Path.rglob at 0x349601d20>

# %%
all_files = [f.resolve() for f in all_files_gen]

# %% [raw]
# all_files

# %%
from pathlib import Path

all_files_gen = Path("/Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/app/files").rglob("*")
all_files = [f.resolve() for f in all_files_gen]

# %%
all_html_files = [f for f in all_files if f.suffix.lower() == ".html"]

# %%
len(all_files)
# Out:
# 14

# %%
# # ... existing code ...

# # Add these lines before the NLTK download
# import ssl
# try:
#     _create_unverified_https_context = ssl._create_unverified_context
# except AttributeError:
#     pass
# else:
#     ssl._create_default_https_context = _create_unverified_https_context

# # Now try downloading
# import nltk
# nltk.download('punkt_tab')
# # ... existing code ...

# %%
# # ... existing code ...

# import ssl
# try:
#     _create_unverified_https_context = ssl._create_unverified_context
# except AttributeError:
#     pass
# else:
#     ssl._create_default_https_context = _create_unverified_https_context
# # 
# import nltk
# nltk.download('punkt')
# nltk.download('averaged_perceptron_tagger')  # This is the correct package name
# nltk.download('universal_tagset')

# # ... existing code ...

# %%
from llama_index.core import Document

# TODO: set to higher value if you want more docs
doc_limit = 100

docs = []
for idx, f in enumerate(all_files):
    if idx > doc_limit:
        break
    print(f"Idx {idx}/{len(all_files)}")
    loaded_docs = reader.load_data(file=f, split_documents=True)
    loaded_doc = Document(
        text="\n\n".join([d.get_content() for d in loaded_docs]),
        metadata={"path": str(f)},
    )
    print(loaded_doc.metadata["path"])
    docs.append(loaded_doc)
# Out:
# Idx 0/14
# WARNING:root:'doc_id' is deprecated and 'id_' will be used instead
# /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/app/files/reglamento-supervision.pdf
# Idx 1/14
# WARNING:root:'doc_id' is deprecated and 'id_' will be used instead
# /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/app/files/LMV.pdf
# Idx 2/14
# WARNING:root:'doc_id' is deprecated and 'id_' will be used instead
# /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/app/files/LTOSF.pdf
# Idx 3/14
# WARNING:root:'doc_id' is deprecated and 'id_' will be used instead
# /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/app/files/file1.pdf
# Idx 4/14
# WARNING:root:'doc_id' is deprecated and 'id_' will be used instead
# /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/app/files/LRITF.pdf
# Idx 5/14
# WARNING:root:'doc_id' is deprecated and 'id_' will be used instead
# /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/app/files/file2.pdf
# Idx 6/14
# WARNING:root:'doc_id' is deprecated and 'id_' will be used instead
# /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/app/files/file3.pdf
# Idx 7/14
# WARNING:root:'doc_id' is deprecated and 'id_' will be used instead
# /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/app/files/file6.pdf
# Idx 8/14
# WARNING:root:'doc_id' is deprecated and 'id_' will be used instead
# /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/app/files/file4.pdf
# Idx 9/14
# WARNING:root:'doc_id' is deprecated and 'id_' will be used instead
# /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/app/files/file5.pdf
# Idx 10/14
# WARNING:root:'doc_id' is deprecated and 'id_' will be used instead
# /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/app/files/LPDUSF.pdf
# Idx 11/14
# WARNING:root:'doc_id' is deprecated and 'id_' will be used instead
# /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/app/files/LGOAAC-2.pdf
# Idx 12/14
# WARNING:root:'doc_id' is deprecated and 'id_' will be used instead
# /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/app/files/LIC.pdf
# Idx 13/14
# WARNING:root:'doc_id' is deprecated and 'id_' will be used instead
# /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/app/files/LGOAAC.pdf

# %% [markdown]
# Define Global LLM + Embeddings

# %%
import os

os.environ["OPENAI_API_KEY"] = "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"

import nest_asyncio

nest_asyncio.apply()

# %%
from llama_index.llms.openai import OpenAI
from llama_index.embeddings.openai import OpenAIEmbedding
from llama_index.core import Settings

llm = OpenAI(model="gpt-4o-mini")
Settings.llm = llm
Settings.embed_model = OpenAIEmbedding(
    model="text-embedding-3-small", embed_batch_size=256
)

# %% [markdown]
# ## Building Multi-Document Agents
#
# In this section we show you how to construct the multi-document agent. We first build a document agent for each document, and then define the top-level parent agent with an object index.

# %% [markdown]
# ### Build Document Agent for each Document
#
# In this section we define "document agents" for each document.
#
# We define both a vector index (for semantic search) and summary index (for summarization) for each document. The two query engines are then converted into tools that are passed to an OpenAI function calling agent.
#
# This document agent can dynamically choose to perform semantic search or summarization within a given document.
#
# We create a separate document agent for each city.

# %%
from llama_index.agent.openai import OpenAIAgent
from llama_index.core import (
    load_index_from_storage,
    StorageContext,
    VectorStoreIndex,
)
from llama_index.core import SummaryIndex
from llama_index.core.tools import QueryEngineTool, ToolMetadata
from llama_index.core.node_parser import SentenceSplitter
import os
from tqdm.notebook import tqdm
import pickle


async def build_agent_per_doc(nodes, file_base):
    print(file_base)

    vi_out_path = f"./data/llamaindex_docs/{file_base}"
    summary_out_path = f"./data/llamaindex_docs/{file_base}_summary.pkl"
    if not os.path.exists(vi_out_path):
        Path("./data/llamaindex_docs/").mkdir(parents=True, exist_ok=True)
        # build vector index
        vector_index = VectorStoreIndex(nodes)
        vector_index.storage_context.persist(persist_dir=vi_out_path)
    else:
        vector_index = load_index_from_storage(
            StorageContext.from_defaults(persist_dir=vi_out_path),
        )

    # build summary index
    summary_index = SummaryIndex(nodes)

    # define query engines
    vector_query_engine = vector_index.as_query_engine(llm=llm)
    summary_query_engine = summary_index.as_query_engine(
        response_mode="tree_summarize", llm=llm
    )

    # extract a summary
    if not os.path.exists(summary_out_path):
        Path(summary_out_path).parent.mkdir(parents=True, exist_ok=True)
        summary = str(
            await summary_query_engine.aquery(
                "Extract a concise 1-2 line summary of this document"
            )
        )
        pickle.dump(summary, open(summary_out_path, "wb"))
    else:
        summary = pickle.load(open(summary_out_path, "rb"))

    # define tools
    query_engine_tools = [
        QueryEngineTool(
            query_engine=vector_query_engine,
            metadata=ToolMetadata(
                name=f"vector_tool_{file_base}",
                description=f"Useful for questions related to specific facts",
            ),
        ),
        QueryEngineTool(
            query_engine=summary_query_engine,
            metadata=ToolMetadata(
                name=f"summary_tool_{file_base}",
                description=f"Useful for summarization questions",
            ),
        ),
    ]

    # build agent
    function_llm = OpenAI(model="gpt-4")
    agent = OpenAIAgent.from_tools(
        query_engine_tools,
        llm=function_llm,
        verbose=True,
        system_prompt=f"""\
You are a specialized agent designed to answer queries about the `{file_base}.html` part of the LlamaIndex docs.
You must ALWAYS use at least one of the tools provided when answering a question; do NOT rely on prior knowledge.\
""",
    )

    return agent, summary


async def build_agents(docs):
    node_parser = SentenceSplitter()

    # Build agents dictionary
    agents_dict = {}
    extra_info_dict = {}

    # # this is for the baseline
    # all_nodes = []

    for idx, doc in enumerate(tqdm(docs)):
        nodes = node_parser.get_nodes_from_documents([doc])
        # all_nodes.extend(nodes)

        # ID will be base + parent
        file_path = Path(doc.metadata["path"])
        file_base = str(file_path.parent.stem) + "_" + str(file_path.stem)
        agent, summary = await build_agent_per_doc(nodes, file_base)

        agents_dict[file_base] = agent
        extra_info_dict[file_base] = {"summary": summary, "nodes": nodes}

    return agents_dict, extra_info_dict

# %%
agents_dict, extra_info_dict = await build_agents(docs)
# Out:
#   0%|          | 0/14 [00:00<?, ?it/s]
# files_reglamento-supervision
# files_LMV
# files_LTOSF
# files_file1
# files_LRITF
# files_file2
# files_file3
# files_file6
# files_file4
# files_file5
# files_LPDUSF
# files_LGOAAC-2
# files_LIC
# files_LGOAAC

# %% [markdown]
# ### Build Retriever-Enabled OpenAI Agent
#
# We build a top-level agent that can orchestrate across the different document agents to answer any user query.
#
# This `RetrieverOpenAIAgent` performs tool retrieval before tool use (unlike a default agent that tries to put all tools in the prompt).
#
# **Improvements from V0**: We make the following improvements compared to the "base" version in V0.
#
# - Adding in reranking: we use Cohere reranker to better filter the candidate set of documents.
# - Adding in a query planning tool: we add an explicit query planning tool that's dynamically created based on the set of retrieved tools.

# %%
# define tool for each document agent
all_tools = []
for file_base, agent in agents_dict.items():
    summary = extra_info_dict[file_base]["summary"]
    doc_tool = QueryEngineTool(
        query_engine=agent,
        metadata=ToolMetadata(
            name=f"tool_{file_base}",
            description=summary, 
        ),
    )
    all_tools.append(doc_tool)

# %%
print(all_tools[0].metadata)
# Out:
# ToolMetadata(description='This document outlines the regulations for the supervision, inspection, and verification of financial institutions by the Comisión Nacional para la Protección y Defensa de los Usuarios de Servicios Financieros, detailing the procedures, responsibilities, and requirements for compliance.', name='tool_files_reglamento-supervision', fn_schema=<class 'llama_index.core.tools.types.DefaultToolFnSchema'>, return_direct=False)

# %%
# define an "object" index and retriever over these tools
from llama_index.core import VectorStoreIndex
from llama_index.core.objects import (
    ObjectIndex,
    ObjectRetriever,
)
from llama_index.postprocessor.cohere_rerank import CohereRerank
from llama_index.core.query_engine import SubQuestionQueryEngine
from llama_index.core.schema import QueryBundle
from llama_index.llms.openai import OpenAI


llm = OpenAI(model_name="gpt-4o")

obj_index = ObjectIndex.from_objects(
    all_tools,
    index_cls=VectorStoreIndex,
)
vector_node_retriever = obj_index.as_node_retriever(
    similarity_top_k=10,
)


# define a custom object retriever that adds in a query planning tool
class CustomObjectRetriever(ObjectRetriever):
    def __init__(
        self,
        retriever,
        object_node_mapping,
        node_postprocessors=None,
        llm=None,
    ):
        self._retriever = retriever
        self._object_node_mapping = object_node_mapping
        self._llm = llm or OpenAI("gpt-4-0613")
        self._node_postprocessors = node_postprocessors or []

    def retrieve(self, query_bundle):
        if isinstance(query_bundle, str):
            query_bundle = QueryBundle(query_str=query_bundle)

        nodes = self._retriever.retrieve(query_bundle)
        for processor in self._node_postprocessors:
            nodes = processor.postprocess_nodes(
                nodes, query_bundle=query_bundle
            )
        tools = [self._object_node_mapping.from_node(n.node) for n in nodes]

        sub_question_engine = SubQuestionQueryEngine.from_defaults(
            query_engine_tools=tools, llm=self._llm
        )
        sub_question_description = f"""\
Useful for any queries that involve comparing multiple documents. ALWAYS use this tool for comparison queries - make sure to call this \
tool with the original query. Do NOT use the other tools for any queries involving multiple documents.
"""
        sub_question_tool = QueryEngineTool(
            query_engine=sub_question_engine,
            metadata=ToolMetadata(
                name="compare_tool", description=sub_question_description
            ),
        )

        return tools + [sub_question_tool]

# %%
os.environ['COHERE_API_KEY'] = "jTH4sPbtG5t33ODpscEdDuf8i3IRarIaAUckF8vI"

# %%
# wrap it with ObjectRetriever to return objects
custom_obj_retriever = CustomObjectRetriever(
    vector_node_retriever,
    obj_index.object_node_mapping,
    node_postprocessors=[CohereRerank(top_n=5)],
    llm=llm,
)

# %%
# %pip install llama-index-question-gen-openai
# Out:
# Collecting llama-index-question-gen-openai
#   Downloading llama_index_question_gen_openai-0.3.0-py3-none-any.whl (2.9 kB)
# Requirement already satisfied: llama-index-core<0.13.0,>=0.12.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-question-gen-openai) (0.12.10.post1)
# Requirement already satisfied: llama-index-llms-openai<0.4.0,>=0.3.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-question-gen-openai) (0.3.13)
# Collecting llama-index-program-openai<0.4.0,>=0.3.0
#   Downloading llama_index_program_openai-0.3.1-py3-none-any.whl (5.3 kB)
# Requirement already satisfied: pydantic>=2.8.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-question-gen-openai) (2.9.2)
# Requirement already satisfied: dataclasses-json in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-question-gen-openai) (0.6.7)
# Requirement already satisfied: requests>=2.31.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-question-gen-openai) (2.32.3)
# Requirement already satisfied: typing-inspect>=0.8.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-question-gen-openai) (0.9.0)
# Requirement already satisfied: pillow>=9.0.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-question-gen-openai) (11.1.0)
# Requirement already satisfied: deprecated>=1.2.9.3 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-question-gen-openai) (1.2.15)
# Requirement already satisfied: SQLAlchemy[asyncio]>=1.4.49 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-question-gen-openai) (2.0.36)
# Requirement already satisfied: numpy in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-question-gen-openai) (1.26.4)
# Requirement already satisfied: wrapt in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-question-gen-openai) (1.17.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-question-gen-openai) (4.67.1)
# Requirement already satisfied: nltk>3.8.1 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-question-gen-openai) (3.9.1)
# Requirement already satisfied: tiktoken>=0.3.3 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-question-gen-openai) (0.8.0)
# Requirement already satisfied: networkx>=3.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-question-gen-openai) (3.4.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-question-gen-openai) (2024.12.0)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-question-gen-openai) (3.11.11)
# Requirement already satisfied: PyYAML>=6.0.1 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-question-gen-openai) (6.0.2)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-question-gen-openai) (1.0.8)
# Requirement already satisfied: typing-extensions>=4.5.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-question-gen-openai) (4.12.2)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-question-gen-openai) (1.2.0)
# Requirement already satisfied: httpx in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-question-gen-openai) (0.28.1)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-question-gen-openai) (9.0.0)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-question-gen-openai) (1.6.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-question-gen-openai) (1.5.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-question-gen-openai) (0.2.1)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-question-gen-openai) (5.0.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-question-gen-openai) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-question-gen-openai) (24.3.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-question-gen-openai) (2.4.4)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-question-gen-openai) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-question-gen-openai) (1.18.3)
# Requirement already satisfied: openai<2.0.0,>=1.58.1 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-llms-openai<0.4.0,>=0.3.0->llama-index-question-gen-openai) (1.59.5)
# Requirement already satisfied: llama-index-agent-openai<0.5.0,>=0.4.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from llama-index-program-openai<0.4.0,>=0.3.0->llama-index-question-gen-openai) (0.4.1)
# Requirement already satisfied: joblib in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-question-gen-openai) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-question-gen-openai) (2024.11.6)
# Requirement already satisfied: click in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-question-gen-openai) (8.1.8)
# Requirement already satisfied: sniffio in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from openai<2.0.0,>=1.58.1->llama-index-llms-openai<0.4.0,>=0.3.0->llama-index-question-gen-openai) (1.3.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from openai<2.0.0,>=1.58.1->llama-index-llms-openai<0.4.0,>=0.3.0->llama-index-question-gen-openai) (0.8.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from openai<2.0.0,>=1.58.1->llama-index-llms-openai<0.4.0,>=0.3.0->llama-index-question-gen-openai) (4.8.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from openai<2.0.0,>=1.58.1->llama-index-llms-openai<0.4.0,>=0.3.0->llama-index-question-gen-openai) (1.9.0)
# Requirement already satisfied: idna>=2.8 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.58.1->llama-index-llms-openai<0.4.0,>=0.3.0->llama-index-question-gen-openai) (3.10)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.58.1->llama-index-llms-openai<0.4.0,>=0.3.0->llama-index-question-gen-openai) (1.2.2)
# Requirement already satisfied: certifi in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-question-gen-openai) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-question-gen-openai) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from httpcore==1.*->httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-question-gen-openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-question-gen-openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-question-gen-openai) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-question-gen-openai) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-question-gen-openai) (2.3.0)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.0->llama-index-question-gen-openai) (3.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-question-gen-openai) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from dataclasses-json->llama-index-core<0.13.0,>=0.12.0->llama-index-question-gen-openai) (3.25.0)
# Requirement already satisfied: packaging>=17.0 in /Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.13.0,>=0.12.0->llama-index-question-gen-openai) (24.2)
# Installing collected packages: llama-index-program-openai, llama-index-question-gen-openai
# Successfully installed llama-index-program-openai-0.3.1 llama-index-question-gen-openai-0.3.0
# WARNING: You are using pip version 21.2.3; however, version 24.3.1 is available.
# You should consider upgrading via the '/Users/inaki/Documents/Personal/Daat/Instrag/front-end/api/.env/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
tmps = custom_obj_retriever.retrieve("hello")

# should be 5 + 1 -- 5 from reranker, 1 from subquestion
print(len(tmps))
# Out:
# 6

# %%
import joblib

# %%
output_dir = Path("./saved_models")
output_dir.mkdir(exist_ok=True)

joblib.dump(custom_obj_retriever._retriever, output_dir / "retriever.joblib")
joblib.dump(custom_obj_retriever._object_node_mapping, output_dir / "object_node_mapping.joblib")
# Out:
# WARNING:root:Removing unpickleable private attribute _client
# WARNING:root:Removing unpickleable private attribute _chunking_tokenizer_fn
# WARNING:root:Removing unpickleable private attribute _split_fns
# WARNING:root:Removing unpickleable private attribute _sub_sentence_split_fns
# ---------------------------------------------------------------------------
# PicklingError                             Traceback (most recent call last)
# Cell In[18], line 5
#       2 output_dir.mkdir(exist_ok=True)
#       4 joblib.dump(custom_obj_retriever._retriever, output_dir / "retriever.joblib")
# ----> 5 joblib.dump(custom_obj_retriever._object_node_mapping, output_dir / "object_node_mapping.joblib")
#
# File ~/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages/joblib/numpy_pickle.py:553, in dump(value, filename, compress, protocol, cache_size)
#     551 elif is_filename:
#     552     with open(filename, 'wb') as f:
# --> 553         NumpyPickler(f, protocol=protocol).dump(value)
#     554 else:
#     555     NumpyPickler(filename, protocol=protocol).dump(value)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/pickle.py:487, in _Pickler.dump(self, obj)
#     485 if self.proto >= 4:
#     486     self.framer.start_framing()
# --> 487 self.save(obj)
#     488 self.write(STOP)
#     489 self.framer.end_framing()
#
# File ~/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages/joblib/numpy_pickle.py:355, in NumpyPickler.save(self, obj)
#     352     wrapper.write_array(obj, self)
#     353     return
# --> 355 return Pickler.save(self, obj)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/pickle.py:603, in _Pickler.save(self, obj, save_persistent_id)
#     599     raise PicklingError("Tuple returned by %s must have "
#     600                         "two to six elements" % reduce)
#     602 # Save the reduce() output and finally memoize the object
# --> 603 self.save_reduce(obj=obj, *rv)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/pickle.py:717, in _Pickler.save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     715 if state is not None:
#     716     if state_setter is None:
# --> 717         save(state)
#     718         write(BUILD)
#     719     else:
#     720         # If a state_setter is specified, call it instead of load_build
#     721         # to update obj's with its previous state.
#     722         # First, push state_setter and its tuple of expected arguments
#     723         # (obj, state) onto the stack.
#
# File ~/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages/joblib/numpy_pickle.py:355, in NumpyPickler.save(self, obj)
#     352     wrapper.write_array(obj, self)
#     353     return
# --> 355 return Pickler.save(self, obj)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/pickle.py:560, in _Pickler.save(self, obj, save_persistent_id)
#     558 f = self.dispatch.get(t)
#     559 if f is not None:
# --> 560     f(self, obj)  # Call unbound method with explicit self
#     561     return
#     563 # Check private dispatch table if any, or else
#     564 # copyreg.dispatch_table
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/pickle.py:972, in _Pickler.save_dict(self, obj)
#     969     self.write(MARK + DICT)
#     971 self.memoize(obj)
# --> 972 self._batch_setitems(obj.items())
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/pickle.py:1003, in _Pickler._batch_setitems(self, items)
#    1001     k, v = tmp[0]
#    1002     save(k)
# -> 1003     save(v)
#    1004     write(SETITEM)
#    1005 # else tmp is empty, and we're done
#
# File ~/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages/joblib/numpy_pickle.py:355, in NumpyPickler.save(self, obj)
#     352     wrapper.write_array(obj, self)
#     353     return
# --> 355 return Pickler.save(self, obj)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/pickle.py:560, in _Pickler.save(self, obj, save_persistent_id)
#     558 f = self.dispatch.get(t)
#     559 if f is not None:
# --> 560     f(self, obj)  # Call unbound method with explicit self
#     561     return
#     563 # Check private dispatch table if any, or else
#     564 # copyreg.dispatch_table
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/pickle.py:972, in _Pickler.save_dict(self, obj)
#     969     self.write(MARK + DICT)
#     971 self.memoize(obj)
# --> 972 self._batch_setitems(obj.items())
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/pickle.py:998, in _Pickler._batch_setitems(self, items)
#     996     for k, v in tmp:
#     997         save(k)
# --> 998         save(v)
#     999     write(SETITEMS)
#    1000 elif n:
#
# File ~/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages/joblib/numpy_pickle.py:355, in NumpyPickler.save(self, obj)
#     352     wrapper.write_array(obj, self)
#     353     return
# --> 355 return Pickler.save(self, obj)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/pickle.py:603, in _Pickler.save(self, obj, save_persistent_id)
#     599     raise PicklingError("Tuple returned by %s must have "
#     600                         "two to six elements" % reduce)
#     602 # Save the reduce() output and finally memoize the object
# --> 603 self.save_reduce(obj=obj, *rv)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/pickle.py:717, in _Pickler.save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     715 if state is not None:
#     716     if state_setter is None:
# --> 717         save(state)
#     718         write(BUILD)
#     719     else:
#     720         # If a state_setter is specified, call it instead of load_build
#     721         # to update obj's with its previous state.
#     722         # First, push state_setter and its tuple of expected arguments
#     723         # (obj, state) onto the stack.
#
#     [... skipping similar frames: NumpyPickler.save at line 355 (1 times)]
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/pickle.py:560, in _Pickler.save(self, obj, save_persistent_id)
#     558 f = self.dispatch.get(t)
#     559 if f is not None:
# --> 560     f(self, obj)  # Call unbound method with explicit self
#     561     return
#     563 # Check private dispatch table if any, or else
#     564 # copyreg.dispatch_table
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/pickle.py:972, in _Pickler.save_dict(self, obj)
#     969     self.write(MARK + DICT)
#     971 self.memoize(obj)
# --> 972 self._batch_setitems(obj.items())
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/pickle.py:998, in _Pickler._batch_setitems(self, items)
#     996     for k, v in tmp:
#     997         save(k)
# --> 998         save(v)
#     999     write(SETITEMS)
#    1000 elif n:
#
#     [... skipping similar frames: NumpyPickler.save at line 355 (1 times)]
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/pickle.py:603, in _Pickler.save(self, obj, save_persistent_id)
#     599     raise PicklingError("Tuple returned by %s must have "
#     600                         "two to six elements" % reduce)
#     602 # Save the reduce() output and finally memoize the object
# --> 603 self.save_reduce(obj=obj, *rv)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/pickle.py:717, in _Pickler.save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     715 if state is not None:
#     716     if state_setter is None:
# --> 717         save(state)
#     718         write(BUILD)
#     719     else:
#     720         # If a state_setter is specified, call it instead of load_build
#     721         # to update obj's with its previous state.
#     722         # First, push state_setter and its tuple of expected arguments
#     723         # (obj, state) onto the stack.
#
#     [... skipping similar frames: NumpyPickler.save at line 355 (2 times), _Pickler._batch_setitems at line 998 (1 times), _Pickler.save at line 560 (1 times), _Pickler.save_dict at line 972 (1 times)]
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/pickle.py:603, in _Pickler.save(self, obj, save_persistent_id)
#     599     raise PicklingError("Tuple returned by %s must have "
#     600                         "two to six elements" % reduce)
#     602 # Save the reduce() output and finally memoize the object
# --> 603 self.save_reduce(obj=obj, *rv)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/pickle.py:717, in _Pickler.save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     715 if state is not None:
#     716     if state_setter is None:
# --> 717         save(state)
#     718         write(BUILD)
#     719     else:
#     720         # If a state_setter is specified, call it instead of load_build
#     721         # to update obj's with its previous state.
#     722         # First, push state_setter and its tuple of expected arguments
#     723         # (obj, state) onto the stack.
#
#     [... skipping similar frames: NumpyPickler.save at line 355 (1 times), _Pickler.save at line 560 (1 times)]
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/pickle.py:972, in _Pickler.save_dict(self, obj)
#     969     self.write(MARK + DICT)
#     971 self.memoize(obj)
# --> 972 self._batch_setitems(obj.items())
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/pickle.py:998, in _Pickler._batch_setitems(self, items)
#     996     for k, v in tmp:
#     997         save(k)
# --> 998         save(v)
#     999     write(SETITEMS)
#    1000 elif n:
#
# File ~/Documents/Personal/Daat/Instrag/front-end/api/.env/lib/python3.10/site-packages/joblib/numpy_pickle.py:355, in NumpyPickler.save(self, obj)
#     352     wrapper.write_array(obj, self)
#     353     return
# --> 355 return Pickler.save(self, obj)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/pickle.py:560, in _Pickler.save(self, obj, save_persistent_id)
#     558 f = self.dispatch.get(t)
#     559 if f is not None:
# --> 560     f(self, obj)  # Call unbound method with explicit self
#     561     return
#     563 # Check private dispatch table if any, or else
#     564 # copyreg.dispatch_table
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/pickle.py:1071, in _Pickler.save_global(self, obj, name)
#    1069     obj2, parent = _getattribute(module, name)
#    1070 except (ImportError, KeyError, AttributeError):
# -> 1071     raise PicklingError(
#    1072         "Can't pickle %r: it's not found as %s.%s" %
#    1073         (obj, module_name, name)) from None
#    1074 else:
#    1075     if obj2 is not obj:
#
# PicklingError: Can't pickle <function OpenAIAgentWorker.__init__.<locals>.<lambda> at 0x34b980790>: it's not found as llama_index.agent.openai.step.OpenAIAgentWorker.__init__.<locals>.<lambda>

# %%
from llama_index.agent.openai import OpenAIAgent
from llama_index.core.agent import ReActAgent

top_agent = OpenAIAgent.from_tools(
    tool_retriever=custom_obj_retriever,
    system_prompt=""" \
You are an agent designed to answer queries about the documentation.
Please always use the tools provided to answer a question. Do not rely on prior knowledge.\

""",
    llm=llm,
    verbose=True,
)

# top_agent = ReActAgent.from_tools(
#     tool_retriever=custom_obj_retriever,
#     system_prompt=""" \
# You are an agent designed to answer queries about the documentation.
# Please always use the tools provided to answer a question. Do not rely on prior knowledge.\

# """,
#     llm=llm,
#     verbose=True,
# )

# %% [markdown]
# ### Define Baseline Vector Store Index
#
# As a point of comparison, we define a "naive" RAG pipeline which dumps all docs into a single vector index collection.
#
# We set the top_k = 4

# %%
all_nodes = [
    n for extra_info in extra_info_dict.values() for n in extra_info["nodes"]
]

# %%
base_index = VectorStoreIndex(all_nodes)
base_query_engine = base_index.as_query_engine(similarity_top_k=4)

# %% [markdown]
# ## Running Example Queries
#
# Let's run some example queries, ranging from QA / summaries over a single document to QA / summarization over multiple documents.

# %%
response = top_agent.query(
    "What types of agents are available in LlamaIndex?",
)
# Out:
# Added user message to memory: What types of agents are available in LlamaIndex?
# === Calling Function ===
# Calling function: tool_files_LMV with args: {"input":"types of agents"}
# Added user message to memory: types of agents
# === Calling Function ===
# Calling function: vector_tool_files_LMV with args: {
#   "input": "types of agents"
# }
# Got output: The types of agents mentioned include:
#
# 1. **Apoderado** - A representative designated by the brokerage firm to execute operations on behalf of the client.
# 2. **Representantes legales** - Legal representatives who are duly accredited to instruct the execution of operations.
# 3. **Personas autorizadas** - Individuals authorized in writing by the client for specific actions as outlined in the contract.
#
# These agents can act on behalf of clients in various capacities related to the execution of financial operations.
# ========================
#
# Got output: The `files_LMV.html` part of the LlamaIndex docs mentions three types of agents:
#
# 1. **Apoderado**: A representative designated by the brokerage firm to execute operations on behalf of the client.
# 2. **Representantes legales**: Legal representatives who are duly accredited to instruct the execution of operations.
# 3. **Personas autorizadas**: Individuals authorized in writing by the client for specific actions as outlined in the contract.
#
# These agents can act on behalf of clients in various capacities related to the execution of financial operations.
# ========================

# %%
print(response)
# Out:
# The types of agents available in LlamaIndex are LLMs (Language Model), Vector Stores, and Agent Tools.

# %%
# baseline
response = base_query_engine.query(
    "What types of agents are available in LlamaIndex?",
)
print(str(response))
# Out:
# LLamaIndex offers various types of agents such as LLMs, vector stores, agent tools, and more.

# %%
response = top_agent.query(
    "Compare the content in the agents page vs. tools page."
)
# Out:
# Added user message to memory: Compare the content in the agents page vs. tools page.
# === Calling Function ===
# Calling function: compare_tool with args: {"input":"agents vs tools"}
# Generated 2 sub questions.
# [tool_understanding_index] Q: What are the functionalities of agents in the Llama Index platform?
# Added user message to memory: What are the functionalities of agents in the Llama Index platform?
# [tool_understanding_index] Q: How do agents differ from tools in the Llama Index platform?
# Added user message to memory: How do agents differ from tools in the Llama Index platform?
# === Calling Function ===
# Calling function: vector_tool_understanding_index with args: {
#   "input": "difference between agents and tools"
# }
# === Calling Function ===
# Calling function: vector_tool_understanding_index with args: {
#   "input": "functionalities of agents"
# }
# Got output: Agents are typically individuals or entities that act on behalf of others, making decisions and taking actions based on predefined rules or instructions. On the other hand, tools are instruments or devices used to carry out specific functions or tasks, often under the control or direction of an agent.
# ========================
#
# Got output: Agents typically have a range of functionalities that allow them to perform tasks autonomously or semi-autonomously. These functionalities may include data collection, analysis, decision-making, communication with other systems or users, and executing specific actions based on predefined rules or algorithms.
# ========================
#
# [tool_understanding_index] A: In the context of the Llama Index platform, agents are entities that make decisions and take actions based on predefined rules or instructions. They are designed to interact with users, understand their queries, and provide appropriate responses.
#
# On the other hand, tools are instruments or devices that are used to perform specific functions or tasks. They are typically controlled or directed by an agent and do not make decisions on their own. They are used to assist the agents in providing accurate and relevant responses to user queries.
# [tool_understanding_index] A: In the Llama Index platform, agents have a variety of functionalities. They can perform tasks autonomously or semi-autonomously. These tasks include data collection and analysis, making decisions, communicating with other systems or users, and executing specific actions. These actions are based on predefined rules or algorithms.
# Got output: Agents in the Llama Index platform are responsible for making decisions and taking actions based on predefined rules or instructions. They interact with users, understand queries, and provide appropriate responses. On the other hand, tools in the platform are instruments or devices used to perform specific functions or tasks. Unlike agents, tools are typically controlled or directed by an agent and do not make decisions independently. Their role is to assist agents in delivering accurate and relevant responses to user queries.
# ========================

# %%
print(response)
# Out:
# The comparison between the content in the agents page and the tools page highlights the difference in their roles and functionalities. Agents on the Llama Index platform are responsible for decision-making and interacting with users, while tools are instruments used to perform specific functions or tasks, controlled by agents to assist in providing responses.

# %%
response = top_agent.query(
    "Can you compare the compact and tree_summarize response synthesizer response modes at a very high-level?"
)
# Out:
# Added user message to memory: Can you compare the compact and tree_summarize response synthesizer response modes at a very high-level?
# === Calling Function ===
# Calling function: compare_tool with args: {"input":"compact response synthesizer response mode, tree_summarize response synthesizer response mode"}
# Generated 5 sub questions.
# [tool_evaluating_index] Q: What is the guidance provided by the tool_evaluating_index on evaluating and understanding a specific topic?
# Added user message to memory: What is the guidance provided by the tool_evaluating_index on evaluating and understanding a specific topic?
# [tool_understanding_index] Q: What insights does the tool_understanding_index offer on understanding concepts related to front-end API testing?
# Added user message to memory: What insights does the tool_understanding_index offer on understanding concepts related to front-end API testing?
# [tool_usage_pattern_index] Q: How does the tool_usage_pattern_index help in evaluating cost analysis based on usage patterns in a front-end API testing environment?
# Added user message to memory: How does the tool_usage_pattern_index help in evaluating cost analysis based on usage patterns in a front-end API testing environment?
# [tool_using_llms_index] Q: How can LLMS be effectively utilized for front-end API testing according to the tool_using_llms_index?
# Added user message to memory: How can LLMS be effectively utilized for front-end API testing according to the tool_using_llms_index?
# [tool_llamahub_index] Q: What information does the tool_llamahub_index provide on understanding loading in Llamahub?
# Added user message to memory: What information does the tool_llamahub_index provide on understanding loading in Llamahub?
# === Calling Function ===
# Calling function: vector_tool_using_llms_index with args: {
#   "input": "front-end API testing"
# }
# === Calling Function ===
# Calling function: vector_tool_llamahub_index with args: {
#   "input": "understanding loading in Llamahub"
# }
# === Calling Function ===
# Calling function: vector_tool_understanding_index with args: {
#   "input": "front-end API testing"
# }
# === Calling Function ===
# Calling function: vector_tool_usage_pattern_index with args: {
#   "input": "cost analysis based on usage patterns in a front-end API testing environment"
# }
# === Calling Function ===
# Calling function: vector_tool_evaluating_index with args: {
#   "input": "guidance on evaluating and understanding a specific topic"
# }
# Got output: The query pertains to testing the front-end API.
# ========================
#
# Got output: The query pertains to testing the front-end API.
# ========================
#
# Got output: To understand loading in Llamahub, you can refer to the documentation located at the specified path.
# ========================
#
# Got output: You can find guidance on evaluating and understanding a specific topic in the provided path.
# ========================
#
# Got output: Cost analysis in a front-end API testing environment is crucial for understanding the financial implications of different usage patterns. By evaluating the cost associated with various usage patterns, organizations can make informed decisions on resource allocation and optimization strategies to ensure efficient and cost-effective testing processes.
# ========================
#
# === Calling Function ===
# Calling function: summary_tool_using_llms_index with args: {
#   "input": "front-end API testing"
# }
# [tool_llamahub_index] A: The `tool_llamahub_index` provides information on understanding loading in Llamahub by referring you to the specific part of the documentation that covers this topic.
# Got output: The query pertains to testing the front-end API.
# ========================
#
# [tool_evaluating_index] A: The tool_evaluating_index provides guidance on evaluating and understanding a specific topic through the provided path. This means that it helps users navigate through the information related to a specific topic, enabling them to evaluate and understand it more effectively.
# [tool_understanding_index] A: The `tool_understanding_index` provides insights into the concept of front-end API testing. It helps in understanding the process of testing the interface and interaction of APIs from the front-end perspective. This includes checking the functionality, reliability, performance, and security of APIs as they interact with front-end applications. The tool can provide specific facts and details related to this concept.
# [tool_using_llms_index] A: I'm sorry, but the tools provided do not provide specific information on how LLMS can be effectively utilized for front-end API testing. The documents may need to be reviewed directly for this information.
# [tool_usage_pattern_index] A: The `tool_usage_pattern_index` helps in evaluating cost analysis based on usage patterns in a front-end API testing environment by providing insights into the usage patterns of different tools. It allows you to understand the frequency and intensity of tool usage, which can be directly linked to the cost involved.
#
# For instance, if a particular tool is used extensively, it might indicate a higher cost due to licensing or maintenance. On the other hand, if a tool is rarely used, it might be more cost-effective to find an alternative or eliminate it altogether.
#
# By analyzing these usage patterns, organizations can make informed decisions about resource allocation, potentially identifying areas where costs can be reduced without compromising the effectiveness of the testing process.
# Got output: The compact response synthesizer provides concise summaries of the information, while the tree_summarize response synthesizer organizes the responses in a structured tree format for better understanding.
# ========================

# %%
print(str(response))
# Out:
# At a very high level, the compact response synthesizer provides concise summaries of the information, while the tree_summarize response synthesizer organizes the responses in a structured tree format for better understanding.
